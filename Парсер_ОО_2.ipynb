# %%
import pandas as pd
import numpy as np
import xlrd
import openpyxl

# %% [markdown]
# В формах ОО-2 разделы 1.1.1 и 3.5 существуют только с 2019 г. - для более поздних форм в соответствующих разделах нужно убруть # в строках

# %%
wb1 = openpyxl.load_workbook(filename = 'Алтайский край (ГОУ) (город+село).xlsx', data_only=True)
wb2	 = openpyxl.load_workbook(filename = 'Амурская область (ГОУ) (город+село).xlsx', data_only=True)
wb3	 = openpyxl.load_workbook(filename = 'Архангельская область (ГОУ) (город+село).xlsx', data_only=True)
wb4	 = openpyxl.load_workbook(filename = 'Астраханская область (ГОУ) (город+село).xlsx', data_only=True)
wb5	 = openpyxl.load_workbook(filename = 'Белгородская область (ГОУ) (город+село).xlsx', data_only=True)
wb6	 = openpyxl.load_workbook(filename = 'Брянская область (ГОУ) (город+село).xlsx', data_only=True)
wb7	 = openpyxl.load_workbook(filename = 'Владимирская область (ГОУ) (город+село).xlsx', data_only=True)
wb8	 = openpyxl.load_workbook(filename = 'Волгоградская область (ГОУ) (город+село).xlsx', data_only=True)
wb9	 = openpyxl.load_workbook(filename = 'Вологодская область (ГОУ) (город+село).xlsx', data_only=True)
wb10	 = openpyxl.load_workbook(filename = 'Воронежская область (ГОУ) (город+село).xlsx', data_only=True)
wb11	 = openpyxl.load_workbook(filename = 'Еврейская автономная область (ГОУ) (город+село).xlsx', data_only=True)
wb12	 = openpyxl.load_workbook(filename = 'Забайкальский край (ГОУ) (город+село).xlsx', data_only=True)
wb13	 = openpyxl.load_workbook(filename = 'Ивановская область (ГОУ) (город+село).xlsx', data_only=True)
wb14	 = openpyxl.load_workbook(filename = 'Иркутская область (ГОУ) (город+село).xlsx', data_only=True)
wb15	 = openpyxl.load_workbook(filename = 'Кабардино-Балкарская Республика (ГОУ) (город+село).xlsx', data_only=True)
wb16	 = openpyxl.load_workbook(filename = 'Калининградская область (ГОУ) (город+село).xlsx', data_only=True)
wb17	 = openpyxl.load_workbook(filename = 'Калужская область (ГОУ) (город+село).xlsx', data_only=True)
wb18	 = openpyxl.load_workbook(filename = 'Камчатский край (ГОУ) (город+село).xlsx', data_only=True)
wb19	 = openpyxl.load_workbook(filename = 'Карачаево-Черкесская Республика (ГОУ) (город+село).xlsx', data_only=True)
wb20	 = openpyxl.load_workbook(filename = 'Кемеровская область (ГОУ) (город+село).xlsx', data_only=True)
wb21	 = openpyxl.load_workbook(filename = 'Кировская область (ГОУ) (город+село).xlsx', data_only=True)
wb22	 = openpyxl.load_workbook(filename = 'Костромская область (ГОУ) (город+село).xlsx', data_only=True)
wb23	 = openpyxl.load_workbook(filename = 'Краснодарский край (ГОУ) (город+село).xlsx', data_only=True)
wb24	 = openpyxl.load_workbook(filename = 'Красноярский край (ГОУ) (город+село).xlsx', data_only=True)
wb25	 = openpyxl.load_workbook(filename = 'Курганская область (ГОУ) (город+село).xlsx', data_only=True)
wb26	 = openpyxl.load_workbook(filename = 'Курская область (ГОУ) (город+село).xlsx', data_only=True)
wb27	 = openpyxl.load_workbook(filename = 'Ленинградская область (ГОУ) (город+село).xlsx', data_only=True)
wb28	 = openpyxl.load_workbook(filename = 'Липецкая область (ГОУ) (город+село).xlsx', data_only=True)
wb29	 = openpyxl.load_workbook(filename = 'Магаданская область (ГОУ) (город+село).xlsx', data_only=True)
wb30	 = openpyxl.load_workbook(filename = 'Москва (ГОУ) (город+село).xlsx', data_only=True)
wb31	 = openpyxl.load_workbook(filename = 'Московская область (ГОУ) (город+село).xlsx', data_only=True)
wb32	 = openpyxl.load_workbook(filename = 'Мурманская область (ГОУ) (город+село).xlsx', data_only=True)
wb33	 = openpyxl.load_workbook(filename = 'Ненецкий автономный округ (ГОУ) (город+село).xlsx', data_only=True)
wb34	 = openpyxl.load_workbook(filename = 'Нижегородская область (ГОУ) (город+село).xlsx', data_only=True)
wb35	 = openpyxl.load_workbook(filename = 'Новгородская область (ГОУ) (город+село).xlsx', data_only=True)
wb36	 = openpyxl.load_workbook(filename = 'Новосибирская область (ГОУ) (город+село).xlsx', data_only=True)
wb37	 = openpyxl.load_workbook(filename = 'Омская область (ГОУ) (город+село).xlsx', data_only=True)
wb38	 = openpyxl.load_workbook(filename = 'Оренбургская область (ГОУ) (город+село).xlsx', data_only=True)
wb39	 = openpyxl.load_workbook(filename = 'Орловская область (ГОУ) (город+село).xlsx', data_only=True)
wb40	 = openpyxl.load_workbook(filename = 'Пензенская область (ГОУ) (город+село).xlsx', data_only=True)
wb41	 = openpyxl.load_workbook(filename = 'Пермский край (ГОУ) (город+село).xlsx', data_only=True)
wb42	 = openpyxl.load_workbook(filename = 'Приморский край (ГОУ) (город+село).xlsx', data_only=True)
wb43	 = openpyxl.load_workbook(filename = 'Псковская область (ГОУ) (город+село).xlsx', data_only=True)
wb44	 = openpyxl.load_workbook(filename = 'Республика Адыгея (ГОУ) (город+село).xlsx', data_only=True)
wb45	 = openpyxl.load_workbook(filename = 'Республика Алтай (ГОУ) (город+село).xlsx', data_only=True)
wb46	 = openpyxl.load_workbook(filename = 'Республика Башкортостан (ГОУ) (город+село).xlsx', data_only=True)
wb47	 = openpyxl.load_workbook(filename = 'Республика Бурятия (ГОУ) (город+село).xlsx', data_only=True)
wb48	 = openpyxl.load_workbook(filename = 'Республика Дагестан (ГОУ) (город+село).xlsx', data_only=True)
wb49	 = openpyxl.load_workbook(filename = 'Республика Ингушетия (ГОУ) (город+село).xlsx', data_only=True)
wb50	 = openpyxl.load_workbook(filename = 'Республика Калмыкия (ГОУ) (город+село).xlsx', data_only=True)
wb51	 = openpyxl.load_workbook(filename = 'Республика Карелия (ГОУ) (город+село).xlsx', data_only=True)
wb52	 = openpyxl.load_workbook(filename = 'Республика Коми (ГОУ) (город+село).xlsx', data_only=True)
wb53	 = openpyxl.load_workbook(filename = 'Республика Крым (ГОУ) (город+село).xlsx', data_only=True)
wb54	 = openpyxl.load_workbook(filename = 'Республика Марий Эл (ГОУ) (город+село).xlsx', data_only=True)
wb55	 = openpyxl.load_workbook(filename = 'Республика Мордовия (ГОУ) (город+село).xlsx', data_only=True)
wb56	 = openpyxl.load_workbook(filename = 'Республика Саха (Якутия) (ГОУ) (город+село).xlsx', data_only=True)
wb57	 = openpyxl.load_workbook(filename = 'Республика Северная Осетия - Алания (ГОУ) (город+село).xlsx', data_only=True)
wb58	 = openpyxl.load_workbook(filename = 'Республика Татарстан (ГОУ) (город+село).xlsx', data_only=True)
wb59	 = openpyxl.load_workbook(filename = 'Республика Тыва (ГОУ) (город+село).xlsx', data_only=True)
wb60	 = openpyxl.load_workbook(filename = 'Республика Хакасия (ГОУ) (город+село).xlsx', data_only=True)
wb61	 = openpyxl.load_workbook(filename = 'Ростовская область (ГОУ) (город+село).xlsx', data_only=True)
wb62	 = openpyxl.load_workbook(filename = 'Рязанская область (ГОУ) (город+село).xlsx', data_only=True)
wb63	 = openpyxl.load_workbook(filename = 'Самарская область (ГОУ) (город+село).xlsx', data_only=True)
wb64	 = openpyxl.load_workbook(filename = 'Санкт-Петербург (ГОУ) (город+село).xlsx', data_only=True)
wb65	 = openpyxl.load_workbook(filename = 'Саратовская область (ГОУ) (город+село).xlsx', data_only=True)
wb66	 = openpyxl.load_workbook(filename = 'Сахалинская область (ГОУ) (город+село).xlsx', data_only=True)
wb67	 = openpyxl.load_workbook(filename = 'Свердловская область (ГОУ) (город+село).xlsx', data_only=True)
wb68	 = openpyxl.load_workbook(filename = 'Севастополь (ГОУ) (город+село).xlsx', data_only=True)
wb69	 = openpyxl.load_workbook(filename = 'Смоленская область (ГОУ) (город+село).xlsx', data_only=True)
wb70	 = openpyxl.load_workbook(filename = 'Ставропольский край (ГОУ) (город+село).xlsx', data_only=True)
wb71	 = openpyxl.load_workbook(filename = 'Тамбовская область (ГОУ) (город+село).xlsx', data_only=True)
wb72	 = openpyxl.load_workbook(filename = 'Тверская область (ГОУ) (город+село).xlsx', data_only=True)
wb73	 = openpyxl.load_workbook(filename = 'Томская область (ГОУ) (город+село).xlsx', data_only=True)
wb74	 = openpyxl.load_workbook(filename = 'Тульская область (ГОУ) (город+село).xlsx', data_only=True)
wb75	 = openpyxl.load_workbook(filename = 'Тюменская область (ГОУ) (город+село).xlsx', data_only=True)
wb76	 = openpyxl.load_workbook(filename = 'Удмуртская Республика (ГОУ) (город+село).xlsx', data_only=True)
wb77	 = openpyxl.load_workbook(filename = 'Ульяновская область (ГОУ) (город+село).xlsx', data_only=True)
wb78	 = openpyxl.load_workbook(filename = 'Хабаровский край (ГОУ) (город+село).xlsx', data_only=True)
wb79	 = openpyxl.load_workbook(filename = 'Ханты-Мансийский автономный округ - Югра (ГОУ) (город+село).xlsx', data_only=True)
wb80	 = openpyxl.load_workbook(filename = 'Челябинская область (ГОУ) (город+село).xlsx', data_only=True)
wb81	 = openpyxl.load_workbook(filename = 'Чеченская Республика (ГОУ) (город+село).xlsx', data_only=True)
wb82	 = openpyxl.load_workbook(filename = 'Чувашская Республика - Чувашия (ГОУ) (город+село).xlsx', data_only=True)
wb83	 = openpyxl.load_workbook(filename = 'Чукотский автономный округ (ГОУ) (город+село).xlsx', data_only=True)
wb84	 = openpyxl.load_workbook(filename = 'Ямало-Ненецкий автономный округ (ГОУ) (город+село).xlsx', data_only=True)
wb85	 = openpyxl.load_workbook(filename = 'Ярославская область (ГОУ) (город+село).xlsx', data_only=True)

# %%
glb = globals()

# %%
for i in range(1, 86):
    i = str(i)
    glb['base' + i] = pd.DataFrame(columns=['regname', 'year'], index = None)
    glb['base' + i]['regname'] = [glb['wb' + i]['Титульный лист']['X29'].value]
    glb['base' + i]['year'] = [glb['wb' + i]['Титульный лист']['AO21'].value]

    glb['base' + i]['water'] = [glb['wb' + i]['Раздел 1.1']['P21'].value]
    glb['base' + i]['canalization'] = [glb['wb' + i]['Раздел 1.1']['Q21'].value]
    glb['base' + i]['heating'] = [glb['wb' + i]['Раздел 1.1']['R21'].value]
    glb['base' + i]['video'] = [glb['wb' + i]['Раздел 1.1']['S21'].value]
    glb['base' + i]['repair'] = [glb['wb' + i]['Раздел 1.1']['T21'].value]
    glb['base' + i]['emergency'] = [glb['wb' + i]['Раздел 1.1']['U21'].value]
    glb['base' + i]['fencing'] = [glb['wb' + i]['Раздел 1.1']['V21'].value]
    glb['base' + i]['security'] = [glb['wb' + i]['Раздел 1.1']['W21'].value]
    glb['base' + i]['firealarm'] = [glb['wb' + i]['Раздел 1.1']['X21'].value]
    glb['base' + i]['smokedetector'] = [glb['wb' + i]['Раздел 1.1']['Y21'].value]
    glb['base' + i]['hydrant'] = [glb['wb' + i]['Раздел 1.1']['Z21'].value]
    glb['base' + i]['alarmbutton'] = [glb['wb' + i]['Раздел 1.1']['AA21'].value]
    glb['base' + i]['lowmobile'] = [glb['wb' + i]['Раздел 1.1']['AB21'].value]

    glb['base' + i]['internetless256kbit'] = [glb['wb' + i]['Раздел 1.1']['AD21'].value]
    glb['base' + i]['internet256_511kbit'] = [glb['wb' + i]['Раздел 1.1']['AE21'].value]
    glb['base' + i]['internet512_999kbit'] = [glb['wb' + i]['Раздел 1.1']['AF21'].value]
    glb['base' + i]['internet1_2mbit'] = [glb['wb' + i]['Раздел 1.1']['AG21'].value]
    glb['base' + i]['internet2_30mbit'] = [glb['wb' + i]['Раздел 1.1']['AH21'].value]
    glb['base' + i]['internet30_50mbit'] = [glb['wb' + i]['Раздел 1.1']['AI21'].value]
    glb['base' + i]['internet50_100mbit'] = [glb['wb' + i]['Раздел 1.1']['AJ21'].value]
    glb['base' + i]['internetmore100mbit'] = [glb['wb' + i]['Раздел 1.1']['AK21'].value]

    glb['base' + i]['explstart'] = [glb['wb' + i]['Раздел 1.1.1']['P21'].value]
    glb['base' + i]['lastrepair'] = [glb['wb' + i]['Раздел 1.1.1']['Q21'].value]

    glb['base' + i]['hall'] = [glb['wb' + i]['Раздел 1.2']['P21'].value]
    glb['base' + i]['gym'] = [glb['wb' + i]['Раздел 1.2']['P22'].value]
    glb['base' + i]['pool'] = [glb['wb' + i]['Раздел 1.2']['P23'].value]
    glb['base' + i]['diningroom'] = [glb['wb' + i]['Раздел 1.2']['P24'].value]
    glb['base' + i]['roomict'] = [glb['wb' + i]['Раздел 1.2']['P25'].value]
    glb['base' + i]['roomphys'] = [glb['wb' + i]['Раздел 1.2']['P26'].value]
    glb['base' + i]['roomchem'] = [glb['wb' + i]['Раздел 1.2']['P27'].value]
    glb['base' + i]['roombio'] = [glb['wb' + i]['Раздел 1.2']['P28'].value]
    glb['base' + i]['roomgeo'] = [glb['wb' + i]['Раздел 1.2']['P29'].value]
    glb['base' + i]['roomextra'] = [glb['wb' + i]['Раздел 1.2']['P30'].value]
    glb['base' + i]['roomsaf'] = [glb['wb' + i]['Раздел 1.2']['P31'].value]
    glb['base' + i]['roomlang'] = [glb['wb' + i]['Раздел 1.2']['P32'].value]
    glb['base' + i]['roomwork'] = [glb['wb' + i]['Раздел 1.2']['P33'].value]
    glb['base' + i]['roomhome'] = [glb['wb' + i]['Раздел 1.2']['P34'].value]
    glb['base' + i]['museum'] = [glb['wb' + i]['Раздел 1.2']['P35'].value]
    glb['base' + i]['eduland'] = [glb['wb' + i]['Раздел 1.2']['P36'].value]
    glb['base' + i]['auditorium'] = [glb['wb' + i]['Раздел 1.2']['P37'].value]
    glb['base' + i]['medical'] = [glb['wb' + i]['Раздел 1.2']['P38'].value]
    glb['base' + i]['logoped'] = [glb['wb' + i]['Раздел 1.2']['P39'].value]
    glb['base' + i]['defectolog'] = [glb['wb' + i]['Раздел 1.2']['P40'].value]
    glb['base' + i]['psycolog'] = [glb['wb' + i]['Раздел 1.2']['P41'].value]
    glb['base' + i]['athletics'] = [glb['wb' + i]['Раздел 1.2']['P42'].value]
    glb['base' + i]['roomtotal'] = [glb['wb' + i]['Раздел 1.2']['P43'].value]
    glb['base' + i]['roomdesk'] = [glb['wb' + i]['Раздел 1.2']['P44'].value]
    glb['base' + i]['roomproj'] = [glb['wb' + i]['Раздел 1.2']['P45'].value]
    glb['base' + i]['roomict_seat'] = [glb['wb' + i]['Раздел 1.2']['P46'].value]

    glb['base' + i]['needdrivenach'] = [glb['wb' + i]['Раздел 1.3']['P21'].value]
    glb['base' + i]['needdriveosn'] = [glb['wb' + i]['Раздел 1.3']['P22'].value]
    glb['base' + i]['needdrivesred'] = [glb['wb' + i]['Раздел 1.3']['P23'].value]
    glb['base' + i]['needdrivetot'] = [glb['wb' + i]['Раздел 1.3']['P24'].value]
    glb['base' + i]['havedrivenach'] = [glb['wb' + i]['Раздел 1.3']['Q21'].value]
    glb['base' + i]['havedriveosn'] = [glb['wb' + i]['Раздел 1.3']['Q22'].value]
    glb['base' + i]['havedrivesred'] = [glb['wb' + i]['Раздел 1.3']['Q23'].value]
    glb['base' + i]['havedrivetot'] = [glb['wb' + i]['Раздел 1.3']['Q24'].value]

    glb['base' + i]['hotfoodnach'] = [glb['wb' + i]['Раздел 1.4']['P21'].value]
    glb['base' + i]['hotfoodosn'] = [glb['wb' + i]['Раздел 1.4']['P22'].value]
    glb['base' + i]['hotfoodsred'] = [glb['wb' + i]['Раздел 1.4']['P23'].value]
    glb['base' + i]['hotfoodtot'] = [glb['wb' + i]['Раздел 1.4']['P24'].value]
    glb['base' + i]['hotfoodnach_free'] = [glb['wb' + i]['Раздел 1.4']['Q21'].value]
    glb['base' + i]['hotfoodosn_free'] = [glb['wb' + i]['Раздел 1.4']['Q22'].value]
    glb['base' + i]['hotfoodsred_free'] = [glb['wb' + i]['Раздел 1.4']['Q23'].value]
    glb['base' + i]['hotfoodtot_free'] = [glb['wb' + i]['Раздел 1.4']['Q24'].value]
    glb['base' + i]['hotfoodnach_break'] = [glb['wb' + i]['Раздел 1.4']['R21'].value]
    glb['base' + i]['hotfoodosn_break'] = [glb['wb' + i]['Раздел 1.4']['R22'].value]
    glb['base' + i]['hotfoodsred_break'] = [glb['wb' + i]['Раздел 1.4']['R23'].value]
    glb['base' + i]['hotfoodtot_break'] = [glb['wb' + i]['Раздел 1.4']['R24'].value]
    glb['base' + i]['hotfoodnach_lanch'] = [glb['wb' + i]['Раздел 1.4']['S21'].value]
    glb['base' + i]['hotfoodosn_lanch'] = [glb['wb' + i]['Раздел 1.4']['S22'].value]
    glb['base' + i]['hotfoodsred_lanch'] = [glb['wb' + i]['Раздел 1.4']['S23'].value]
    glb['base' + i]['hotfoodtot_lanch'] = [glb['wb' + i]['Раздел 1.4']['S24'].value]
    glb['base' + i]['hotfoodnach_both'] = [glb['wb' + i]['Раздел 1.4']['T21'].value]
    glb['base' + i]['hotfoodosn_both'] = [glb['wb' + i]['Раздел 1.4']['T22'].value]
    glb['base' + i]['hotfoodsred_both'] = [glb['wb' + i]['Раздел 1.4']['T23'].value]
    glb['base' + i]['hotfoodtot_both'] = [glb['wb' + i]['Раздел 1.4']['T24'].value]

    glb['base' + i]['sch_internat'] = [glb['wb' + i]['Раздел 1.6']['P22'].value]
    glb['base' + i]['sch_haveinternat'] = [glb['wb' + i]['Раздел 1.6']['P23'].value]
    glb['base' + i]['sch_vech'] = [glb['wb' + i]['Раздел 1.6']['P24'].value]
    glb['base' + i]['sch_havevech'] = [glb['wb' + i]['Раздел 1.6']['P25'].value]
    glb['base' + i]['sch_ovz'] = [glb['wb' + i]['Раздел 1.6']['P26'].value]
    glb['base' + i]['sch_ovzdeaf'] = [glb['wb' + i]['Раздел 1.6']['P27'].value]
    glb['base' + i]['sch_ovzhear'] = [glb['wb' + i]['Раздел 1.6']['P28'].value]
    glb['base' + i]['sch_ovzblind'] = [glb['wb' + i]['Раздел 1.6']['P29'].value]
    glb['base' + i]['sch_ovzvis'] = [glb['wb' + i]['Раздел 1.6']['P30'].value]
    glb['base' + i]['sch_ovzspeech'] = [glb['wb' + i]['Раздел 1.6']['P31'].value]
    glb['base' + i]['sch_ovzdis'] = [glb['wb' + i]['Раздел 1.6']['P32'].value]
    glb['base' + i]['sch_ovzmental'] = [glb['wb' + i]['Раздел 1.6']['P33'].value]
    glb['base' + i]['sch_ovzautist'] = [glb['wb' + i]['Раздел 1.6']['P34'].value]
    glb['base' + i]['sch_ovzdefect'] = [glb['wb' + i]['Раздел 1.6']['P35'].value]
    glb['base' + i]['sch_ovzother'] = [glb['wb' + i]['Раздел 1.6']['P36'].value]
    glb['base' + i]['sch_ovzclasses'] = [glb['wb' + i]['Раздел 1.6']['P37'].value]
    glb['base' + i]['sch_deviant'] = [glb['wb' + i]['Раздел 1.6']['P38'].value]
    glb['base' + i]['sch_deviantnach'] = [glb['wb' + i]['Раздел 1.6']['P39'].value]
    glb['base' + i]['sch_deviantlong'] = [glb['wb' + i]['Раздел 1.6']['P40'].value]
    glb['base' + i]['sch_deviantpsyh'] = [glb['wb' + i]['Раздел 1.6']['P41'].value]
    glb['base' + i]['sch_deviantorphant'] = [glb['wb' + i]['Раздел 1.6']['P42'].value]
    glb['base' + i]['sch_deviantcenrte'] = [glb['wb' + i]['Раздел 1.6']['P43'].value]
    glb['base' + i]['sch_deviantpenal'] = [glb['wb' + i]['Раздел 1.6']['P44'].value]
    glb['base' + i]['sch_adv'] = [glb['wb' + i]['Раздел 1.6']['P45'].value]
    glb['base' + i]['sch_advclasses'] = [glb['wb' + i]['Раздел 1.6']['P46'].value]
    glb['base' + i]['sch_advgymn'] = [glb['wb' + i]['Раздел 1.6']['P47'].value]
    glb['base' + i]['sch_advgymnclasses'] = [glb['wb' + i]['Раздел 1.6']['P48'].value]
    glb['base' + i]['sch_advlyc'] = [glb['wb' + i]['Раздел 1.6']['P49'].value]
    glb['base' + i]['sch_advlycclasses'] = [glb['wb' + i]['Раздел 1.6']['P50'].value]
    glb['base' + i]['sch_mil'] = [glb['wb' + i]['Раздел 1.6']['P51'].value]
    glb['base' + i]['sch_milsuv'] = [glb['wb' + i]['Раздел 1.6']['P52'].value]
    glb['base' + i]['sch_milnakh'] = [glb['wb' + i]['Раздел 1.6']['P53'].value]
    glb['base' + i]['sch_milcadmil'] = [glb['wb' + i]['Раздел 1.6']['P54'].value]
    glb['base' + i]['sch_milcad'] = [glb['wb' + i]['Раздел 1.6']['P55'].value]
    glb['base' + i]['sch_milcadsch'] = [glb['wb' + i]['Раздел 1.6']['P56'].value]
    glb['base' + i]['sch_milcosscad'] = [glb['wb' + i]['Раздел 1.6']['P57'].value]
    glb['base' + i]['sch_milmusic'] = [glb['wb' + i]['Раздел 1.6']['P58'].value]
    glb['base' + i]['sch_other'] = [glb['wb' + i]['Раздел 1.6']['P59'].value]
    glb['base' + i]['sch_simple'] = [glb['wb' + i]['Раздел 1.6']['P60'].value]

    glb['base' + i]['comp'] = [glb['wb' + i]['Раздел 2.1']['P21'].value]
    glb['base' + i]['comp_laptop'] = [glb['wb' + i]['Раздел 2.1']['P22'].value]
    glb['base' + i]['comp_tablet'] = [glb['wb' + i]['Раздел 2.1']['P23'].value]
    glb['base' + i]['comp_local'] = [glb['wb' + i]['Раздел 2.1']['P24'].value]
    glb['base' + i]['comp_internet'] = [glb['wb' + i]['Раздел 2.1']['P25'].value]
    glb['base' + i]['comp_intranet'] = [glb['wb' + i]['Раздел 2.1']['P26'].value]
    glb['base' + i]['comp_new'] = [glb['wb' + i]['Раздел 2.1']['P27'].value]
    glb['base' + i]['infomat'] = [glb['wb' + i]['Раздел 2.1']['P28'].value]
    glb['base' + i]['infomat_internet'] = [glb['wb' + i]['Раздел 2.1']['P29'].value]
    glb['base' + i]['projector'] = [glb['wb' + i]['Раздел 2.1']['P30'].value]
    glb['base' + i]['multidesk'] = [glb['wb' + i]['Раздел 2.1']['P31'].value]
    glb['base' + i]['printer'] = [glb['wb' + i]['Раздел 2.1']['P32'].value]
    glb['base' + i]['scaner'] = [glb['wb' + i]['Раздел 2.1']['P33'].value]
    glb['base' + i]['mfu'] = [glb['wb' + i]['Раздел 2.1']['P34'].value]
    glb['base' + i]['xerox'] = [glb['wb' + i]['Раздел 2.1']['P35'].value]
    glb['base' + i]['comp'] = [glb['wb' + i]['Раздел 2.1']['Q21'].value]
    glb['base' + i]['comp_laptop_learn'] = [glb['wb' + i]['Раздел 2.1']['Q22'].value]
    glb['base' + i]['comp_tablet_learn'] = [glb['wb' + i]['Раздел 2.1']['Q23'].value]
    glb['base' + i]['comp_local_learn'] = [glb['wb' + i]['Раздел 2.1']['Q24'].value]
    glb['base' + i]['comp_internet_learn'] = [glb['wb' + i]['Раздел 2.1']['Q25'].value]
    glb['base' + i]['comp_intranet_learn'] = [glb['wb' + i]['Раздел 2.1']['Q26'].value]
    glb['base' + i]['comp_new_learn'] = [glb['wb' + i]['Раздел 2.1']['Q27'].value]
    glb['base' + i]['comp_use'] = [glb['wb' + i]['Раздел 2.1']['R21'].value]
    glb['base' + i]['comp_laptop_use'] = [glb['wb' + i]['Раздел 2.1']['R22'].value]
    glb['base' + i]['comp_tablet_use'] = [glb['wb' + i]['Раздел 2.1']['R23'].value]
    glb['base' + i]['comp_local_use'] = [glb['wb' + i]['Раздел 2.1']['R24'].value]
    glb['base' + i]['comp_internet_use'] = [glb['wb' + i]['Раздел 2.1']['R25'].value]
    glb['base' + i]['comp_intranet_use'] = [glb['wb' + i]['Раздел 2.1']['R26'].value]
    glb['base' + i]['comp_new_use'] = [glb['wb' + i]['Раздел 2.1']['R27'].value]

    glb['base' + i]['program_learn'] = [glb['wb' + i]['Раздел 2.2']['P21'].value]
    glb['base' + i]['testing_learn'] = [glb['wb' + i]['Раздел 2.2']['P22'].value]
    glb['base' + i]['encycl_learn'] = [glb['wb' + i]['Раздел 2.2']['P23'].value]
    glb['base' + i]['testbook_learn'] = [glb['wb' + i]['Раздел 2.2']['P24'].value]
    glb['base' + i]['textbook_learn'] = [glb['wb' + i]['Раздел 2.2']['P25'].value]
    glb['base' + i]['diglibrary_learn'] = [glb['wb' + i]['Раздел 2.2']['P26'].value]
    glb['base' + i]['journal_learn'] = [glb['wb' + i]['Раздел 2.2']['P27'].value]
    glb['base' + i]['reference_learn'] = [glb['wb' + i]['Раздел 2.2']['P28'].value]
    glb['base' + i]['manage_learn'] = [glb['wb' + i]['Раздел 2.2']['P29'].value]
    glb['base' + i]['docunent_learn'] = [glb['wb' + i]['Раздел 2.2']['P30'].value]
    glb['base' + i]['filter_learn'] = [glb['wb' + i]['Раздел 2.2']['P31'].value]
    glb['base' + i]['progother_learn'] = [glb['wb' + i]['Раздел 2.2']['P32'].value]
    glb['base' + i]['program_use'] = [glb['wb' + i]['Раздел 2.2']['Q21'].value]
    glb['base' + i]['testing_use'] = [glb['wb' + i]['Раздел 2.2']['Q22'].value]
    glb['base' + i]['encycl_use'] = [glb['wb' + i]['Раздел 2.2']['Q23'].value]
    glb['base' + i]['testbook_use'] = [glb['wb' + i]['Раздел 2.2']['Q24'].value]
    glb['base' + i]['textbook_use'] = [glb['wb' + i]['Раздел 2.2']['Q25'].value]
    glb['base' + i]['diglibrary_use'] = [glb['wb' + i]['Раздел 2.2']['Q26'].value]
    glb['base' + i]['journal_use'] = [glb['wb' + i]['Раздел 2.2']['Q27'].value]
    glb['base' + i]['reference_use'] = [glb['wb' + i]['Раздел 2.2']['Q28'].value]
    glb['base' + i]['manage_use'] = [glb['wb' + i]['Раздел 2.2']['Q29'].value]
    glb['base' + i]['docunent_use'] = [glb['wb' + i]['Раздел 2.2']['Q30'].value]
    glb['base' + i]['filter_use'] = [glb['wb' + i]['Раздел 2.2']['Q31'].value]
    glb['base' + i]['progother_use'] = [glb['wb' + i]['Раздел 2.2']['Q32'].value]

    glb['base' + i]['intmaxspeed_prov_no'] = [glb['wb' + i]['Раздел 2.3']['P22'].value]
    glb['base' + i]['intmaxspeed_prov_less256kbit'] = [glb['wb' + i]['Раздел 2.3']['Q22'].value]
    glb['base' + i]['intmaxspeed_prov_256_511kbit'] = [glb['wb' + i]['Раздел 2.3']['R22'].value]
    glb['base' + i]['intmaxspeed_prov_521_999kbit'] = [glb['wb' + i]['Раздел 2.3']['S22'].value]
    glb['base' + i]['intmaxspeed_prov_1_2mbit'] = [glb['wb' + i]['Раздел 2.3']['T22'].value]
    glb['base' + i]['intmaxspeed_prov_2_30mbit'] = [glb['wb' + i]['Раздел 2.3']['U22'].value]
    glb['base' + i]['intmaxspeed_prov_30_50mbit'] = [glb['wb' + i]['Раздел 2.3']['V22'].value]
    glb['base' + i]['intmaxspeed_prov_50_100mbit'] = [glb['wb' + i]['Раздел 2.3']['W22'].value]
    glb['base' + i]['intmaxspeed_prov_more100mbit'] = [glb['wb' + i]['Раздел 2.3']['X22'].value]
    glb['base' + i]['intmaxspeed_besprov_no'] = [glb['wb' + i]['Раздел 2.3']['P23'].value]
    glb['base' + i]['intmaxspeed_besprov_less256kbit'] = [glb['wb' + i]['Раздел 2.3']['Q23'].value]
    glb['base' + i]['intmaxspeed_besprov_256_511kbit'] = [glb['wb' + i]['Раздел 2.3']['R23'].value]
    glb['base' + i]['intmaxspeed_besprov_521_999kbit'] = [glb['wb' + i]['Раздел 2.3']['S23'].value]
    glb['base' + i]['intmaxspeed_besprov_1_2mbit'] = [glb['wb' + i]['Раздел 2.3']['T23'].value]
    glb['base' + i]['intmaxspeed_besprov_2_30mbit'] = [glb['wb' + i]['Раздел 2.3']['U23'].value]
    glb['base' + i]['intmaxspeed_besprov_30_50mbit'] = [glb['wb' + i]['Раздел 2.3']['V23'].value]
    glb['base' + i]['intmaxspeed_besprov_50_100mbit'] = [glb['wb' + i]['Раздел 2.3']['W23'].value]
    glb['base' + i]['intmaxspeed_besprov_more100mbit'] = [glb['wb' + i]['Раздел 2.3']['X23'].value]
    glb['base' + i]['intmaxspeed_mob_no'] = [glb['wb' + i]['Раздел 2.3']['P24'].value]
    glb['base' + i]['intmaxspeed_mob_less256kbit'] = [glb['wb' + i]['Раздел 2.3']['Q24'].value]
    glb['base' + i]['intmaxspeed_mob_256_511kbit'] = [glb['wb' + i]['Раздел 2.3']['R24'].value]
    glb['base' + i]['intmaxspeed_mob_521_999kbit'] = [glb['wb' + i]['Раздел 2.3']['S24'].value]
    glb['base' + i]['intmaxspeed_mob_1_2mbit'] = [glb['wb' + i]['Раздел 2.3']['T24'].value]
    glb['base' + i]['intmaxspeed_mob_2_30mbit'] = [glb['wb' + i]['Раздел 2.3']['U24'].value]
    glb['base' + i]['intmaxspeed_mob_30_50mbit'] = [glb['wb' + i]['Раздел 2.3']['V24'].value]
    glb['base' + i]['intmaxspeed_mob_50_100mbit'] = [glb['wb' + i]['Раздел 2.3']['W24'].value]
    glb['base' + i]['intmaxspeed_mob_more100mbit'] = [glb['wb' + i]['Раздел 2.3']['X24'].value]

    glb['base' + i]['telephone'] = [glb['wb' + i]['Раздел 2.4']['P21'].value]
    glb['base' + i]['email'] = [glb['wb' + i]['Раздел 2.4']['P22'].value]
    glb['base' + i]['website'] = [glb['wb' + i]['Раздел 2.4']['P23'].value]
    glb['base' + i]['webinfo'] = [glb['wb' + i]['Раздел 2.4']['P24'].value]
    glb['base' + i]['busgov'] = [glb['wb' + i]['Раздел 2.4']['P25'].value]

    glb['base' + i]['electnach'] = [glb['wb' + i]['Раздел 2.5']['P21'].value]
    glb['base' + i]['electosn'] = [glb['wb' + i]['Раздел 2.5']['Q21'].value]
    glb['base' + i]['electsred'] = [glb['wb' + i]['Раздел 2.5']['R21'].value]
    glb['base' + i]['distnach'] = [glb['wb' + i]['Раздел 2.5']['P22'].value]
    glb['base' + i]['distosn'] = [glb['wb' + i]['Раздел 2.5']['Q22'].value]
    glb['base' + i]['distsred'] = [glb['wb' + i]['Раздел 2.5']['R22'].value]

    glb['base' + i]['library_add'] = [glb['wb' + i]['Раздел 2.6']['P21'].value]
    glb['base' + i]['library_textbooks_add'] = [glb['wb' + i]['Раздел 2.6']['P22'].value]
    glb['base' + i]['library_testbooks_add'] = [glb['wb' + i]['Раздел 2.6']['P23'].value]
    glb['base' + i]['library_lit_add'] = [glb['wb' + i]['Раздел 2.6']['P24'].value]
    glb['base' + i]['library_ref_add'] = [glb['wb' + i]['Раздел 2.6']['P25'].value]
    glb['base' + i]['library_print_add'] = [glb['wb' + i]['Раздел 2.6']['P26'].value]
    glb['base' + i]['library_audio_add'] = [glb['wb' + i]['Раздел 2.6']['P27'].value]
    glb['base' + i]['library_micro_add'] = [glb['wb' + i]['Раздел 2.6']['P28'].value]
    glb['base' + i]['library_electr_add'] = [glb['wb' + i]['Раздел 2.6']['P29'].value]
    glb['base' + i]['library_gone'] = [glb['wb' + i]['Раздел 2.6']['Q21'].value]
    glb['base' + i]['library_textbooks_gone'] = [glb['wb' + i]['Раздел 2.6']['Q22'].value]
    glb['base' + i]['library_testbooks_gone'] = [glb['wb' + i]['Раздел 2.6']['Q23'].value]
    glb['base' + i]['library_lit_gone'] = [glb['wb' + i]['Раздел 2.6']['Q24'].value]
    glb['base' + i]['library_ref_gone'] = [glb['wb' + i]['Раздел 2.6']['Q25'].value]
    glb['base' + i]['library_print_gone'] = [glb['wb' + i]['Раздел 2.6']['Q26'].value]
    glb['base' + i]['library_audio_gone'] = [glb['wb' + i]['Раздел 2.6']['Q27'].value]
    glb['base' + i]['library_micro_gone'] = [glb['wb' + i]['Раздел 2.6']['Q28'].value]
    glb['base' + i]['library_electr_gone'] = [glb['wb' + i]['Раздел 2.6']['Q29'].value]
    glb['base' + i]['library_tot'] = [glb['wb' + i]['Раздел 2.6']['R21'].value]
    glb['base' + i]['library_textbooks_tot'] = [glb['wb' + i]['Раздел 2.6']['R22'].value]
    glb['base' + i]['library_testbooks_tot'] = [glb['wb' + i]['Раздел 2.6']['R23'].value]
    glb['base' + i]['library_lit_tot'] = [glb['wb' + i]['Раздел 2.6']['R24'].value]
    glb['base' + i]['library_ref_tot'] = [glb['wb' + i]['Раздел 2.6']['R25'].value]
    glb['base' + i]['library_print_tot'] = [glb['wb' + i]['Раздел 2.6']['R26'].value]
    glb['base' + i]['library_audio_tot'] = [glb['wb' + i]['Раздел 2.6']['R27'].value]
    glb['base' + i]['library_micro_tot'] = [glb['wb' + i]['Раздел 2.6']['R28'].value]
    glb['base' + i]['library_electr_tot'] = [glb['wb' + i]['Раздел 2.6']['R29'].value]

    glb['base' + i]['funding_tot'] = [glb['wb' + i]['Раздел 3.1']['P21'].value]
    glb['base' + i]['funding_bud_tot'] = [glb['wb' + i]['Раздел 3.1']['P22'].value]
    glb['base' + i]['funding_budfed_tot'] = [glb['wb' + i]['Раздел 3.1']['P23'].value]
    glb['base' + i]['funding_budreg_tot'] = [glb['wb' + i]['Раздел 3.1']['P24'].value]
    glb['base' + i]['funding_budmun_tot'] = [glb['wb' + i]['Раздел 3.1']['P25'].value]
    glb['base' + i]['funding_org_tot'] = [glb['wb' + i]['Раздел 3.1']['P26'].value]
    glb['base' + i]['funding_people_tot'] = [glb['wb' + i]['Раздел 3.1']['P27'].value]
    glb['base' + i]['funding_outbud_tot'] = [glb['wb' + i]['Раздел 3.1']['P28'].value]
    glb['base' + i]['funding_for_tot'] = [glb['wb' + i]['Раздел 3.1']['P29'].value]
    glb['base' + i]['funding_edu'] = [glb['wb' + i]['Раздел 3.1']['Q21'].value]
    glb['base' + i]['funding_bud_edu'] = [glb['wb' + i]['Раздел 3.1']['Q22'].value]
    glb['base' + i]['funding_budfed_edu'] = [glb['wb' + i]['Раздел 3.1']['Q23'].value]
    glb['base' + i]['funding_budreg_edu'] = [glb['wb' + i]['Раздел 3.1']['Q24'].value]
    glb['base' + i]['funding_budmun_edu'] = [glb['wb' + i]['Раздел 3.1']['Q25'].value]
    glb['base' + i]['funding_org_edu'] = [glb['wb' + i]['Раздел 3.1']['Q26'].value]
    glb['base' + i]['funding_people_edu'] = [glb['wb' + i]['Раздел 3.1']['Q27'].value]
    glb['base' + i]['funding_outbud_edu'] = [glb['wb' + i]['Раздел 3.1']['Q28'].value]
    glb['base' + i]['funding_for_edu'] = [glb['wb' + i]['Раздел 3.1']['Q29'].value]
    glb['base' + i]['funding_oth'] = [glb['wb' + i]['Раздел 3.1']['R21'].value]
    glb['base' + i]['funding_bud_oth'] = [glb['wb' + i]['Раздел 3.1']['R22'].value]
    glb['base' + i]['funding_budfed_oth'] = [glb['wb' + i]['Раздел 3.1']['R23'].value]
    glb['base' + i]['funding_budreg_oth'] = [glb['wb' + i]['Раздел 3.1']['R24'].value]
    glb['base' + i]['funding_budmun_oth'] = [glb['wb' + i]['Раздел 3.1']['R25'].value]
    glb['base' + i]['funding_org_oth'] = [glb['wb' + i]['Раздел 3.1']['R26'].value]
    glb['base' + i]['funding_people_oth'] = [glb['wb' + i]['Раздел 3.1']['R27'].value]
    glb['base' + i]['funding_outbud_oth'] = [glb['wb' + i]['Раздел 3.1']['R28'].value]
    glb['base' + i]['funding_for_oth'] = [glb['wb' + i]['Раздел 3.1']['R29'].value]

    glb['base' + i]['expence_tot'] = [glb['wb' + i]['Раздел 3.2']['P21'].value]
    glb['base' + i]['expence_wage_tot'] = [glb['wb' + i]['Раздел 3.2']['P22'].value]
    glb['base' + i]['expence_wage_salary_tot'] = [glb['wb' + i]['Раздел 3.2']['P23'].value]
    glb['base' + i]['expence_wage_oth_tot'] = [glb['wb' + i]['Раздел 3.2']['P24'].value]
    glb['base' + i]['expence_wage_acc_tot'] = [glb['wb' + i]['Раздел 3.2']['P25'].value]
    glb['base' + i]['expence_pay_tot'] = [glb['wb' + i]['Раздел 3.2']['P26'].value]
    glb['base' + i]['expence_pay_comm_tot'] = [glb['wb' + i]['Раздел 3.2']['P27'].value]
    glb['base' + i]['expence_pay_trans_tot'] = [glb['wb' + i]['Раздел 3.2']['P28'].value]
    glb['base' + i]['expence_pay_util_tot'] = [glb['wb' + i]['Раздел 3.2']['P29'].value]
    glb['base' + i]['expence_pay_arend_tot'] = [glb['wb' + i]['Раздел 3.2']['P30'].value]
    glb['base' + i]['expence_pay__prop_tot'] = [glb['wb' + i]['Раздел 3.2']['P31'].value]
    glb['base' + i]['expence_pay_oth_tot'] = [glb['wb' + i]['Раздел 3.2']['P32'].value]
    glb['base' + i]['expence_soc_tot'] = [glb['wb' + i]['Раздел 3.2']['P33'].value]
    glb['base' + i]['expence_oth_tot'] = [glb['wb' + i]['Раздел 3.2']['P34'].value]
    glb['base' + i]['assets_tot'] = [glb['wb' + i]['Раздел 3.2']['P35'].value]
    glb['base' + i]['assets_fix_tot'] = [glb['wb' + i]['Раздел 3.2']['P36'].value]
    glb['base' + i]['assets_intan_tot'] = [glb['wb' + i]['Раздел 3.2']['P37'].value]
    glb['base' + i]['assets_non_tot'] = [glb['wb' + i]['Раздел 3.2']['P38'].value]
    glb['base' + i]['assets_invent_tot'] = [glb['wb' + i]['Раздел 3.2']['P39'].value]
    glb['base' + i]['expence_bud'] = [glb['wb' + i]['Раздел 3.2']['Q21'].value]
    glb['base' + i]['expence_wage_bud'] = [glb['wb' + i]['Раздел 3.2']['Q22'].value]
    glb['base' + i]['expence_wage_salary_bud'] = [glb['wb' + i]['Раздел 3.2']['Q23'].value]
    glb['base' + i]['expence_wage_oth_bud'] = [glb['wb' + i]['Раздел 3.2']['Q24'].value]
    glb['base' + i]['expence_wage_acc_bud'] = [glb['wb' + i]['Раздел 3.2']['Q25'].value]
    glb['base' + i]['expence_pay_bud'] = [glb['wb' + i]['Раздел 3.2']['Q26'].value]
    glb['base' + i]['expence_pay_comm_bud'] = [glb['wb' + i]['Раздел 3.2']['Q27'].value]
    glb['base' + i]['expence_pay_trans_bud'] = [glb['wb' + i]['Раздел 3.2']['Q28'].value]
    glb['base' + i]['expence_pay_util_bud'] = [glb['wb' + i]['Раздел 3.2']['Q29'].value]
    glb['base' + i]['expence_pay_arend_bud'] = [glb['wb' + i]['Раздел 3.2']['Q30'].value]
    glb['base' + i]['expence_pay__prop_bud'] = [glb['wb' + i]['Раздел 3.2']['Q31'].value]
    glb['base' + i]['expence_pay_oth_bud'] = [glb['wb' + i]['Раздел 3.2']['Q32'].value]
    glb['base' + i]['expence_soc_bud'] = [glb['wb' + i]['Раздел 3.2']['Q33'].value]
    glb['base' + i]['expence_oth_bud'] = [glb['wb' + i]['Раздел 3.2']['Q34'].value]
    glb['base' + i]['assets_bud'] = [glb['wb' + i]['Раздел 3.2']['Q35'].value]
    glb['base' + i]['assets_fix_bud'] = [glb['wb' + i]['Раздел 3.2']['Q36'].value]
    glb['base' + i]['assets_intan_bud'] = [glb['wb' + i]['Раздел 3.2']['Q37'].value]
    glb['base' + i]['assets_non_bud'] = [glb['wb' + i]['Раздел 3.2']['Q38'].value]
    glb['base' + i]['assets_invent_bud'] = [glb['wb' + i]['Раздел 3.2']['Q39'].value]
    glb['base' + i]['expence_gov'] = [glb['wb' + i]['Раздел 3.2']['R21'].value]
    glb['base' + i]['expence_wage_gov'] = [glb['wb' + i]['Раздел 3.2']['R22'].value]
    glb['base' + i]['expence_wage_salary_gov'] = [glb['wb' + i]['Раздел 3.2']['R23'].value]
    glb['base' + i]['expence_wage_oth_gov'] = [glb['wb' + i]['Раздел 3.2']['R24'].value]
    glb['base' + i]['expence_wage_acc_gov'] = [glb['wb' + i]['Раздел 3.2']['R25'].value]
    glb['base' + i]['expence_pay_gov'] = [glb['wb' + i]['Раздел 3.2']['R26'].value]
    glb['base' + i]['expence_pay_comm_gov'] = [glb['wb' + i]['Раздел 3.2']['R27'].value]
    glb['base' + i]['expence_pay_trans_gov'] = [glb['wb' + i]['Раздел 3.2']['R28'].value]
    glb['base' + i]['expence_pay_util_gov'] = [glb['wb' + i]['Раздел 3.2']['R29'].value]
    glb['base' + i]['expence_pay_arend_gov'] = [glb['wb' + i]['Раздел 3.2']['R30'].value]
    glb['base' + i]['expence_pay__prop_gov'] = [glb['wb' + i]['Раздел 3.2']['R31'].value]
    glb['base' + i]['expence_pay_oth_gov'] = [glb['wb' + i]['Раздел 3.2']['R32'].value]
    glb['base' + i]['expence_soc_gov'] = [glb['wb' + i]['Раздел 3.2']['R33'].value]
    glb['base' + i]['expence_oth_gov'] = [glb['wb' + i]['Раздел 3.2']['R34'].value]
    glb['base' + i]['assets_gov'] = [glb['wb' + i]['Раздел 3.2']['R35'].value]
    glb['base' + i]['assets_fix_gov'] = [glb['wb' + i]['Раздел 3.2']['R36'].value]
    glb['base' + i]['assets_intan_gov'] = [glb['wb' + i]['Раздел 3.2']['R37'].value]
    glb['base' + i]['assets_non_gov'] = [glb['wb' + i]['Раздел 3.2']['R38'].value]
    glb['base' + i]['assets_invent_gov'] = [glb['wb' + i]['Раздел 3.2']['R39'].value]


    glb['base' + i]['pers_n'] = [glb['wb' + i]['Раздел 3.3']['P21'].value]
    glb['base' + i]['pers_top_n'] = [glb['wb' + i]['Раздел 3.3']['P22'].value]
    glb['base' + i]['pers_top_dir_n'] = [glb['wb' + i]['Раздел 3.3']['P23'].value]
    glb['base' + i]['pers_ped_n'] = [glb['wb' + i]['Раздел 3.3']['P24'].value]
    glb['base' + i]['pers_ped_teach_n'] = [glb['wb' + i]['Раздел 3.3']['P25'].value]
    glb['base' + i]['pers_ped_dop_n'] = [glb['wb' + i]['Раздел 3.3']['P26'].value]
    glb['base' + i]['pers_assist_n'] = [glb['wb' + i]['Раздел 3.3']['P27'].value]
    glb['base' + i]['pers_oth_n'] = [glb['wb' + i]['Раздел 3.3']['P28'].value]
    glb['base' + i]['pers_ped_kid_n'] = [glb['wb' + i]['Раздел 3.3']['P29'].value]
    glb['base' + i]['pers_ped_kid_vosp_n'] = [glb['wb' + i]['Раздел 3.3']['P30'].value]
    glb['base' + i]['pers_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q21'].value]
    glb['base' + i]['pers_top_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q22'].value]
    glb['base' + i]['pers_top_dir_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q23'].value]
    glb['base' + i]['pers_ped_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q24'].value]
    glb['base' + i]['pers_ped_teach_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q25'].value]
    glb['base' + i]['pers_ped_dop_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q26'].value]
    glb['base' + i]['pers_assist_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q27'].value]
    glb['base' + i]['pers_oth_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q28'].value]
    glb['base' + i]['pers_ped_kid_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q29'].value]
    glb['base' + i]['pers_ped_kid_vosp_n_vn'] = [glb['wb' + i]['Раздел 3.3']['Q30'].value]
    glb['base' + i]['pers_wage'] = [glb['wb' + i]['Раздел 3.3']['R21'].value]
    glb['base' + i]['pers_top_wage'] = [glb['wb' + i]['Раздел 3.3']['R22'].value]
    glb['base' + i]['pers_top_dir_wage'] = [glb['wb' + i]['Раздел 3.3']['R23'].value]
    glb['base' + i]['pers_ped_wage'] = [glb['wb' + i]['Раздел 3.3']['R24'].value]
    glb['base' + i]['pers_ped_teach_wage'] = [glb['wb' + i]['Раздел 3.3']['R25'].value]
    glb['base' + i]['pers_ped_dop_wage'] = [glb['wb' + i]['Раздел 3.3']['R26'].value]
    glb['base' + i]['pers_assist_wage'] = [glb['wb' + i]['Раздел 3.3']['R27'].value]
    glb['base' + i]['pers_oth_wage'] = [glb['wb' + i]['Раздел 3.3']['R28'].value]
    glb['base' + i]['pers_ped_kid_wage'] = [glb['wb' + i]['Раздел 3.3']['R29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage'] = [glb['wb' + i]['Раздел 3.3']['R30'].value]
    glb['base' + i]['pers_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S21'].value]
    glb['base' + i]['pers_top_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S22'].value]
    glb['base' + i]['pers_top_dir_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S23'].value]
    glb['base' + i]['pers_ped_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S24'].value]
    glb['base' + i]['pers_ped_teach_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S25'].value]
    glb['base' + i]['pers_ped_dop_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S26'].value]
    glb['base' + i]['pers_assist_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S27'].value]
    glb['base' + i]['pers_oth_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S28'].value]
    glb['base' + i]['pers_ped_kid_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage_vnut'] = [glb['wb' + i]['Раздел 3.3']['S30'].value]
    glb['base' + i]['pers_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T21'].value]
    glb['base' + i]['pers_top_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T22'].value]
    glb['base' + i]['pers_top_dir_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T23'].value]
    glb['base' + i]['pers_ped_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T24'].value]
    glb['base' + i]['pers_ped_teach_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T25'].value]
    glb['base' + i]['pers_ped_dop_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T26'].value]
    glb['base' + i]['pers_assist_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T27'].value]
    glb['base' + i]['pers_oth_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T28'].value]
    glb['base' + i]['pers_ped_kid_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage_vn'] = [glb['wb' + i]['Раздел 3.3']['T30'].value]
    glb['base' + i]['pers_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U21'].value]
    glb['base' + i]['pers_top_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U22'].value]
    glb['base' + i]['pers_top_dir_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U23'].value]
    glb['base' + i]['pers_ped_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U24'].value]
    glb['base' + i]['pers_ped_teach_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U25'].value]
    glb['base' + i]['pers_ped_dop_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U26'].value]
    glb['base' + i]['pers_assist_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U27'].value]
    glb['base' + i]['pers_oth_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U28'].value]
    glb['base' + i]['pers_ped_kid_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage_bud'] = [glb['wb' + i]['Раздел 3.3']['U30'].value]
    glb['base' + i]['pers_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W21'].value]
    glb['base' + i]['pers_top_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W22'].value]
    glb['base' + i]['pers_top_dir_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W23'].value]
    glb['base' + i]['pers_ped_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W24'].value]
    glb['base' + i]['pers_ped_teach_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W25'].value]
    glb['base' + i]['pers_ped_dop_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W26'].value]
    glb['base' + i]['pers_assist_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W27'].value]
    glb['base' + i]['pers_oth_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W28'].value]
    glb['base' + i]['pers_ped_kid_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage_earn'] = [glb['wb' + i]['Раздел 3.3']['W30'].value]
    glb['base' + i]['pers_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X21'].value]
    glb['base' + i]['pers_top_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X22'].value]
    glb['base' + i]['pers_top_dir_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X23'].value]
    glb['base' + i]['pers_ped_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X24'].value]
    glb['base' + i]['pers_ped_teach_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X25'].value]
    glb['base' + i]['pers_ped_dop_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X26'].value]
    glb['base' + i]['pers_assist_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X27'].value]
    glb['base' + i]['pers_oth_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X28'].value]
    glb['base' + i]['pers_ped_kid_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage_bud_vn'] = [glb['wb' + i]['Раздел 3.3']['X30'].value]
    glb['base' + i]['pers_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z21'].value]
    glb['base' + i]['pers_top_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z22'].value]
    glb['base' + i]['pers_top_dir_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z23'].value]
    glb['base' + i]['pers_ped_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z24'].value]
    glb['base' + i]['pers_ped_teach_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z25'].value]
    glb['base' + i]['pers_ped_dop_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z26'].value]
    glb['base' + i]['pers_assist_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z27'].value]
    glb['base' + i]['pers_oth_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z28'].value]
    glb['base' + i]['pers_ped_kid_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z29'].value]
    glb['base' + i]['pers_ped_kid_vosp_wage_earn_vn'] = [glb['wb' + i]['Раздел 3.3']['Z30'].value]

    glb['base' + i]['costtech'] = [glb['wb' + i]['Раздел 3.5']['P21'].value]
    glb['base' + i]['costserv'] = [glb['wb' + i]['Раздел 3.5']['P22'].value]
    glb['base' + i]['costint'] = [glb['wb' + i]['Раздел 3.5']['P23'].value]
    glb['base' + i]['costintbuy'] = [glb['wb' + i]['Раздел 3.5']['P24'].value]
    glb['base' + i]['costintbuydev'] = [glb['wb' + i]['Раздел 3.5']['P25'].value]
    glb['base' + i]['costintbuycomm'] = [glb['wb' + i]['Раздел 3.5']['P26'].value]
    glb['base' + i]['costintporus'] = [glb['wb' + i]['Раздел 3.5']['P27'].value]
    glb['base' + i]['costintpo'] = [glb['wb' + i]['Раздел 3.5']['P28'].value]
    glb['base' + i]['costintcomm'] = [glb['wb' + i]['Раздел 3.5']['P29'].value]
    glb['base' + i]['costintweb'] = [glb['wb' + i]['Раздел 3.5']['P30'].value]
    glb['base' + i]['costintcont'] = [glb['wb' + i]['Раздел 3.5']['P31'].value]
    glb['base' + i]['costext'] = [glb['wb' + i]['Раздел 3.5']['P32'].value]
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# <ipython-input-10-44513af13f7c>:182: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   glb['base' + i]['filter_use'] = [glb['wb' + i]['Раздел 2.2']['Q31'].value]
# <ipython-input-10-44513af13f7c>:183: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   glb['base' + i]['progother_use'] = [glb['wb' + i]['Раздел 2.2']['Q32'].value]
# ...

# %%
oo_2_2016 = base1

# %%
for i in range(2, 86):
    i = str(i)
    oo_2_2016 = pd.concat([oo_2_2016, glb['base' + i]])

# %%
oo_2_2016.to_excel('oo2_2022-23.xlsx', index = False, encoding = 'unicode8')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)

# %%
oo_2_2016_20 = pd.concat([oo_2_2016, oo_2_2017, oo_2_2018, oo_2_2019, oo_2_2020])

# %%
oo_2_2016_20.to_excel('oo2_2016-20.xlsx', index = False, encoding = 'unicode8')

# %%
oo_16 = pd.read_excel('ОО_2_2016-2023.xlsx')

# %%
oo_2_2016.head(2)
# Out:
#                                regname  year  water  canalization  heating  \
# 0    Алтайский край (ГОУ) (город+село)  2022   1571          1568     1583
# 1  Амурская область (ГОУ) (город+село)  2022    509           502      511
#
#    video  repair emergency  fencing  security  ...    costint  costintbuy  \
# 0    926     489         8     1493      1022  ...   221764.7    116522.9
# 1    433     111         2      509       506  ...  3778208.3   1873323.1
#
#    costintbuydev  costintbuycomm  costintporus costintpo costintcomm  \
# 0        94507.1          6839.3        8964.2    4988.5     85447.3
# 1      1240426.0          4783.5       14482.5    7136.6    539991.8
#
#   costintweb costintcont  costext
# 0    13175.9      1592.5  22401.7
# 1   377589.4   1374897.5    451.1
#
# [2 rows x 421 columns]

# %%
oo_16.head(2)
# Out:
#           regname  year  water  canalization  heating  video  repair  \
# 0  Алтайский край  2016   1445          1442     1353    370   172.0
# 1  Алтайский край  2017   1448          1426     1327    420   205.0
#
#    emergency  fencing  security  ...  costintbuy  costintbuydev  \
# 0        NaN     1406       967  ...         NaN            NaN
# 1        NaN     1391       914  ...         NaN            NaN
#
#    costintbuycomm  costintporus  costintpo  costintcomm  costintweb  \
# 0             NaN           NaN        NaN          NaN         NaN
# 1             NaN           NaN        NaN          NaN         NaN
#
#    costintcont  costext       _merge
# 0          NaN      NaN  Matched (3)
# 1          NaN      NaN  Matched (3)
#
# [2 rows x 422 columns]

# %%
result = pd.concat([oo_16, oo_2_2016], axis=1)

# %%
oo_16 = oo_16.reset_index(drop=True)

# %%
oo_2_2016 = oo_2_2016.reset_index(drop=True)

# %%
result.tail(2)
# Out:
#                  regname  year  water  canalization  heating  video  repair  \
# 508  Ярославская область  2020    549           549      549    519    20.0
# 509  Ярославская область  2021    542           542      542    537    39.0
#
#      emergency  fencing  security  ...  costint  costintbuy  costintbuydev  \
# 508        NaN      517       456  ...      NaN         NaN            NaN
# 509        NaN      534       541  ...      NaN         NaN            NaN
#
#      costintbuycomm  costintporus  costintpo  costintcomm  costintweb  \
# 508             NaN           NaN        NaN          NaN         NaN
# 509             NaN           NaN        NaN          NaN         NaN
#
#      costintcont  costext
# 508          NaN      NaN
# 509          NaN      NaN
#
# [2 rows x 843 columns]

# %%
result.to_excel('oo2_2016-23_try.xlsx', index = False, encoding = 'unicode8')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
