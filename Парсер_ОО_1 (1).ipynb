# %%
import pandas as pd
import numpy as np
import xlrd
import openpyxl

# %% [markdown]
# Этот парсер собирает данные из региональных форм OO1 образца 2016 г. и позже.
# Для корректной работы парсера лучше предварительно скачать региональные формы в папку на своем компьютере
# ссылка на формы для скачивания: http://eis.mon.gov.ru/education/SitePages/%D0%9E%D0%B1%D1%89%D0%B5%D0%B5%20%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5-%D0%A4%D0%BE%D1%80%D0%BC%D1%8B_2018-2020.aspx?&&View={5E5E8321-ED60-48BE-AFC0-6C6F6E1C32AB}#ltab1_3
# Путь к скачанным файлам необходимо указать в строках, начинающихся с wb по образцу filename = 'Your_path/формаОО1_Алтай.xlsx', data_only=True
# Можно вместо ссылки на файл в системе указать ссылку на каждую форму на сайте, но так парсер работает дольше

# %%
wb1 = openpyxl.load_workbook(filename = 'Алтайский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb2	 = openpyxl.load_workbook(filename = 'Амурская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb3	 = openpyxl.load_workbook(filename = 'Архангельская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb4	 = openpyxl.load_workbook(filename = 'Астраханская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb5	 = openpyxl.load_workbook(filename = 'Белгородская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb6	 = openpyxl.load_workbook(filename = 'Брянская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb7	 = openpyxl.load_workbook(filename = 'Владимирская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb8	 = openpyxl.load_workbook(filename = 'Волгоградская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb9	 = openpyxl.load_workbook(filename = 'Вологодская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb10	 = openpyxl.load_workbook(filename = 'Воронежская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb11	 = openpyxl.load_workbook(filename = 'Еврейская автономная область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb12	 = openpyxl.load_workbook(filename = 'Забайкальский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb13	 = openpyxl.load_workbook(filename = 'Ивановская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb14	 = openpyxl.load_workbook(filename = 'Иркутская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb15	 = openpyxl.load_workbook(filename = 'Кабардино-Балкарская Республика (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb16	 = openpyxl.load_workbook(filename = 'Калининградская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb17	 = openpyxl.load_workbook(filename = 'Калужская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb18	 = openpyxl.load_workbook(filename = 'Камчатский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb19	 = openpyxl.load_workbook(filename = 'Карачаево-Черкесская Республика (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb20	 = openpyxl.load_workbook(filename = 'Кемеровская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb21	 = openpyxl.load_workbook(filename = 'Кировская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb22	 = openpyxl.load_workbook(filename = 'Костромская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb23	 = openpyxl.load_workbook(filename = 'Краснодарский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb24	 = openpyxl.load_workbook(filename = 'Красноярский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb25	 = openpyxl.load_workbook(filename = 'Курганская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb26	 = openpyxl.load_workbook(filename = 'Курская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb27	 = openpyxl.load_workbook(filename = 'Ленинградская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb28	 = openpyxl.load_workbook(filename = 'Липецкая область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb29	 = openpyxl.load_workbook(filename = 'Магаданская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb30	 = openpyxl.load_workbook(filename = 'Москва (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb31	 = openpyxl.load_workbook(filename = 'Московская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb32	 = openpyxl.load_workbook(filename = 'Мурманская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb33	 = openpyxl.load_workbook(filename = 'Ненецкий автономный округ (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb34	 = openpyxl.load_workbook(filename = 'Нижегородская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb35	 = openpyxl.load_workbook(filename = 'Новгородская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb36	 = openpyxl.load_workbook(filename = 'Новосибирская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb37	 = openpyxl.load_workbook(filename = 'Омская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb38	 = openpyxl.load_workbook(filename = 'Оренбургская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb39	 = openpyxl.load_workbook(filename = 'Орловская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb40	 = openpyxl.load_workbook(filename = 'Пензенская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb41	 = openpyxl.load_workbook(filename = 'Пермский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb42	 = openpyxl.load_workbook(filename = 'Приморский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb43	 = openpyxl.load_workbook(filename = 'Псковская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb44	 = openpyxl.load_workbook(filename = 'Республика Адыгея (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb45	 = openpyxl.load_workbook(filename = 'Республика Алтай (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb46	 = openpyxl.load_workbook(filename = 'Республика Башкортостан (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb47	 = openpyxl.load_workbook(filename = 'Республика Бурятия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb48	 = openpyxl.load_workbook(filename = 'Республика Дагестан (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb49	 = openpyxl.load_workbook(filename = 'Республика Ингушетия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb50	 = openpyxl.load_workbook(filename = 'Республика Калмыкия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb51	 = openpyxl.load_workbook(filename = 'Республика Карелия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb52	 = openpyxl.load_workbook(filename = 'Республика Коми (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb53	 = openpyxl.load_workbook(filename = 'Республика Крым (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb54	 = openpyxl.load_workbook(filename = 'Республика Марий Эл (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb55	 = openpyxl.load_workbook(filename = 'Республика Мордовия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb56	 = openpyxl.load_workbook(filename = 'Республика Саха (Якутия) (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb57	 = openpyxl.load_workbook(filename = 'Республика Северная Осетия — Алания (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb58	 = openpyxl.load_workbook(filename = 'Республика Татарстан (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb59	 = openpyxl.load_workbook(filename = 'Республика Тыва (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb60	 = openpyxl.load_workbook(filename = 'Республика Хакасия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb61	 = openpyxl.load_workbook(filename = 'Ростовская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb62	 = openpyxl.load_workbook(filename = 'Рязанская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb63	 = openpyxl.load_workbook(filename = 'Самарская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb64	 = openpyxl.load_workbook(filename = 'Санкт-Петербург (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb65	 = openpyxl.load_workbook(filename = 'Саратовская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb66	 = openpyxl.load_workbook(filename = 'Сахалинская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb67	 = openpyxl.load_workbook(filename = 'Свердловская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb68	 = openpyxl.load_workbook(filename = 'Севастополь (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb69	 = openpyxl.load_workbook(filename = 'Смоленская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb70	 = openpyxl.load_workbook(filename = 'Ставропольский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb71	 = openpyxl.load_workbook(filename = 'Тамбовская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb72	 = openpyxl.load_workbook(filename = 'Тверская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb73	 = openpyxl.load_workbook(filename = 'Томская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb74	 = openpyxl.load_workbook(filename = 'Тульская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb75	 = openpyxl.load_workbook(filename = 'Тюменская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb76	 = openpyxl.load_workbook(filename = 'Удмуртская Республика (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb77	 = openpyxl.load_workbook(filename = 'Ульяновская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb78	 = openpyxl.load_workbook(filename = 'Хабаровский край (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb79	 = openpyxl.load_workbook(filename = 'Ханты-Мансийский автономный округ — Югра (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb80	 = openpyxl.load_workbook(filename = 'Челябинская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb81	 = openpyxl.load_workbook(filename = 'Чеченская Республика (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb82	 = openpyxl.load_workbook(filename = 'Чувашская Республика — Чувашия (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb83	 = openpyxl.load_workbook(filename = 'Чукотский автономный округ (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb84	 = openpyxl.load_workbook(filename = 'Ямало-Ненецкий автономный округ (ГОУ+НОУ) (город+село).xlsx', data_only=True)
wb85	 = openpyxl.load_workbook(filename = 'Ярославская область (ГОУ+НОУ) (город+село).xlsx', data_only=True)

# %%
glb = globals()

# %%
for i in range(1, 86):
    i = str(i)
    glb['base' + i] = pd.DataFrame(columns=['regname', 'year', 'license', 'accreditation', 'pedsovet', 'popsovet'], index = None)
    glb['base' + i]['regname'] = [glb['wb' + i]['Титульный лист']['X29'].value]
    glb['base' + i]['year'] = [glb['wb' + i]['Титульный лист']['AM20'].value]

    glb['base' + i]['license'] = [glb['wb' + i]['Раздел 1.1']['P21'].value]
    glb['base' + i]['accreditation'] = [glb['wb' + i]['Раздел 1.1']['P22'].value]
    glb['base' + i]['pedsovet'] = [glb['wb' + i]['Раздел 1.1']['P25'].value]
    glb['base' + i]['popsovet'] = [glb['wb' + i]['Раздел 1.1']['P26'].value]
    glb['base' + i]['uprsovet'] = [glb['wb' + i]['Раздел 1.1']['P27'].value]
    glb['base' + i]['nablsovet'] = [glb['wb' + i]['Раздел 1.1']['P28'].value]
    glb['base' + i]['studsovet'] = [glb['wb' + i]['Раздел 1.1']['P30'].value]
    glb['base' + i]['parsovet'] = [glb['wb' + i]['Раздел 1.1']['P31'].value]
    glb['base' + i]['uprsovet'] = [glb['wb' + i]['Раздел 1.1']['P27'].value]

    glb['base' + i]['internat'] = [glb['wb' + i]['Раздел 1.2']['P22'].value]
    glb['base' + i]['ovz'] = [glb['wb' + i]['Раздел 1.2']['P26'].value]
    glb['base' + i]['deviant'] = [glb['wb' + i]['Раздел 1.2']['P38'].value]
    glb['base' + i]['profclass'] = [glb['wb' + i]['Раздел 1.2']['P46'].value]
    glb['base' + i]['gymnasium'] = [glb['wb' + i]['Раздел 1.2']['P47'].value]
    glb['base' + i]['liceum'] = [glb['wb' + i]['Раздел 1.2']['P49'].value]

    glb['base' + i]['nnach'] = [glb['wb' + i]['Раздел 1.3']['P21'].value]
    glb['base' + i]['nobsh'] = [glb['wb' + i]['Раздел 1.3']['P31'].value]
    glb['base' + i]['nsred'] = [glb['wb' + i]['Раздел 1.3']['P41'].value]

    glb['base' + i]['nnachset'] = [glb['wb' + i]['Раздел 1.3']['Q21'].value]
    glb['base' + i]['nobshset'] = [glb['wb' + i]['Раздел 1.3']['Q31'].value]
    glb['base' + i]['nsredset'] = [glb['wb' + i]['Раздел 1.3']['Q41'].value]

    glb['base' + i]['nnachel'] = [glb['wb' + i]['Раздел 1.3']['S21'].value]
    glb['base' + i]['nobshel'] = [glb['wb' + i]['Раздел 1.3']['S31'].value]
    glb['base' + i]['nsredel'] = [glb['wb' + i]['Раздел 1.3']['S41'].value]

    glb['base' + i]['nnachdist'] = [glb['wb' + i]['Раздел 1.3']['U21'].value]
    glb['base' + i]['nobshdist'] = [glb['wb' + i]['Раздел 1.3']['U31'].value]
    glb['base' + i]['nsreddist'] = [glb['wb' + i]['Раздел 1.3']['U41'].value]

    glb['base' + i]['nclasses'] = [glb['wb' + i]['Раздел 2.1.1']['P29'].value]
    glb['base' + i]['nclasses1'] = [glb['wb' + i]['Раздел 2.1.1']['Q29'].value]
    glb['base' + i]['nclasses2'] = [glb['wb' + i]['Раздел 2.1.1']['R29'].value]
    glb['base' + i]['nclasses3'] = [glb['wb' + i]['Раздел 2.1.1']['S29'].value]
    glb['base' + i]['nclasses4'] = [glb['wb' + i]['Раздел 2.1.1']['T29'].value]
    glb['base' + i]['nclasses5'] = [glb['wb' + i]['Раздел 2.1.1']['U29'].value]
    glb['base' + i]['nclasses6'] = [glb['wb' + i]['Раздел 2.1.1']['V29'].value]
    glb['base' + i]['nclasses7'] = [glb['wb' + i]['Раздел 2.1.1']['W29'].value]
    glb['base' + i]['nclasses8'] = [glb['wb' + i]['Раздел 2.1.1']['X29'].value]
    glb['base' + i]['nclasses9'] = [glb['wb' + i]['Раздел 2.1.1']['Y29'].value]
    glb['base' + i]['nclasses10'] = [glb['wb' + i]['Раздел 2.1.1']['Z29'].value]
    glb['base' + i]['nclasses11'] = [glb['wb' + i]['Раздел 2.1.1']['AA29'].value]

    glb['base' + i]['nclassesprof'] = [glb['wb' + i]['Раздел 2.1.1']['P23'].value]
    glb['base' + i]['nclassesprof1'] = [glb['wb' + i]['Раздел 2.1.1']['Q23'].value]
    glb['base' + i]['nclassesprof2'] = [glb['wb' + i]['Раздел 2.1.1']['R23'].value]
    glb['base' + i]['nclassesprof3'] = [glb['wb' + i]['Раздел 2.1.1']['S23'].value]
    glb['base' + i]['nclassesprof4'] = [glb['wb' + i]['Раздел 2.1.1']['T23'].value]
    glb['base' + i]['nclassesprof5'] = [glb['wb' + i]['Раздел 2.1.1']['U23'].value]
    glb['base' + i]['nclassesprof6'] = [glb['wb' + i]['Раздел 2.1.1']['V23'].value]
    glb['base' + i]['nclassesprof7'] = [glb['wb' + i]['Раздел 2.1.1']['W23'].value]
    glb['base' + i]['nclassesprof8'] = [glb['wb' + i]['Раздел 2.1.1']['X23'].value]
    glb['base' + i]['nclassesprof9'] = [glb['wb' + i]['Раздел 2.1.1']['Y23'].value]
    glb['base' + i]['nclassesprof10'] = [glb['wb' + i]['Раздел 2.1.1']['Z23'].value]
    glb['base' + i]['nclassesprof11'] = [glb['wb' + i]['Раздел 2.1.1']['AA23'].value]

    glb['base' + i]['nstud'] = [glb['wb' + i]['Раздел 2.1.1']['P30'].value]
    glb['base' + i]['nstud1'] = [glb['wb' + i]['Раздел 2.1.1']['Q30'].value]
    glb['base' + i]['nstud2'] = [glb['wb' + i]['Раздел 2.1.1']['R30'].value]
    glb['base' + i]['nstud3'] = [glb['wb' + i]['Раздел 2.1.1']['S30'].value]
    glb['base' + i]['nstud4'] = [glb['wb' + i]['Раздел 2.1.1']['T30'].value]
    glb['base' + i]['nstud5'] = [glb['wb' + i]['Раздел 2.1.1']['U30'].value]
    glb['base' + i]['nstud6'] = [glb['wb' + i]['Раздел 2.1.1']['V30'].value]
    glb['base' + i]['nstud7'] = [glb['wb' + i]['Раздел 2.1.1']['W30'].value]
    glb['base' + i]['nstud8'] = [glb['wb' + i]['Раздел 2.1.1']['X30'].value]
    glb['base' + i]['nstud9'] = [glb['wb' + i]['Раздел 2.1.1']['Y30'].value]
    glb['base' + i]['nstud10'] = [glb['wb' + i]['Раздел 2.1.1']['Z30'].value]
    glb['base' + i]['nstud11'] = [glb['wb' + i]['Раздел 2.1.1']['AA30'].value]

    glb['base' + i]['nstudprof'] = [glb['wb' + i]['Раздел 2.1.1']['P24'].value]
    glb['base' + i]['nstudprof1'] = [glb['wb' + i]['Раздел 2.1.1']['Q24'].value]
    glb['base' + i]['nstudprof2'] = [glb['wb' + i]['Раздел 2.1.1']['R24'].value]
    glb['base' + i]['nstudprof3'] = [glb['wb' + i]['Раздел 2.1.1']['S24'].value]
    glb['base' + i]['nstudprof4'] = [glb['wb' + i]['Раздел 2.1.1']['T24'].value]
    glb['base' + i]['nstudprof5'] = [glb['wb' + i]['Раздел 2.1.1']['U24'].value]
    glb['base' + i]['nstudprof6'] = [glb['wb' + i]['Раздел 2.1.1']['V24'].value]
    glb['base' + i]['nstudprof7'] = [glb['wb' + i]['Раздел 2.1.1']['W24'].value]
    glb['base' + i]['nstudprof8'] = [glb['wb' + i]['Раздел 2.1.1']['X24'].value]
    glb['base' + i]['nstudprof9'] = [glb['wb' + i]['Раздел 2.1.1']['Y24'].value]
    glb['base' + i]['nstudprof10'] = [glb['wb' + i]['Раздел 2.1.1']['Z24'].value]
    glb['base' + i]['nstudprof11'] = [glb['wb' + i]['Раздел 2.1.1']['AA24'].value]

    glb['base' + i]['nclassesgym'] = [glb['wb' + i]['Раздел 2.1.1']['P25'].value]
    glb['base' + i]['nclassesgym1'] = [glb['wb' + i]['Раздел 2.1.1']['Q25'].value]
    glb['base' + i]['nclassesgym2'] = [glb['wb' + i]['Раздел 2.1.1']['R25'].value]
    glb['base' + i]['nclassesgym3'] = [glb['wb' + i]['Раздел 2.1.1']['S25'].value]
    glb['base' + i]['nclassesgym4'] = [glb['wb' + i]['Раздел 2.1.1']['T25'].value]
    glb['base' + i]['nclassesgym5'] = [glb['wb' + i]['Раздел 2.1.1']['U25'].value]
    glb['base' + i]['nclassesgym6'] = [glb['wb' + i]['Раздел 2.1.1']['V25'].value]
    glb['base' + i]['nclassesgym7'] = [glb['wb' + i]['Раздел 2.1.1']['W25'].value]
    glb['base' + i]['nclassesgym8'] = [glb['wb' + i]['Раздел 2.1.1']['X25'].value]
    glb['base' + i]['nclassesgym9'] = [glb['wb' + i]['Раздел 2.1.1']['Y25'].value]
    glb['base' + i]['nclassesgym10'] = [glb['wb' + i]['Раздел 2.1.1']['Z25'].value]
    glb['base' + i]['nclassesgym11'] = [glb['wb' + i]['Раздел 2.1.1']['AA25'].value]

    glb['base' + i]['nstudgym'] = [glb['wb' + i]['Раздел 2.1.1']['P26'].value]
    glb['base' + i]['nstudgym1'] = [glb['wb' + i]['Раздел 2.1.1']['Q26'].value]
    glb['base' + i]['nstudgym2'] = [glb['wb' + i]['Раздел 2.1.1']['R26'].value]
    glb['base' + i]['nstudgym3'] = [glb['wb' + i]['Раздел 2.1.1']['S26'].value]
    glb['base' + i]['nstudgym4'] = [glb['wb' + i]['Раздел 2.1.1']['T26'].value]
    glb['base' + i]['nstudgym5'] = [glb['wb' + i]['Раздел 2.1.1']['U26'].value]
    glb['base' + i]['nstudgym6'] = [glb['wb' + i]['Раздел 2.1.1']['V26'].value]
    glb['base' + i]['nstudgym7'] = [glb['wb' + i]['Раздел 2.1.1']['W26'].value]
    glb['base' + i]['nstudgym8'] = [glb['wb' + i]['Раздел 2.1.1']['X26'].value]
    glb['base' + i]['nstudgym9'] = [glb['wb' + i]['Раздел 2.1.1']['Y26'].value]
    glb['base' + i]['nstudgym10'] = [glb['wb' + i]['Раздел 2.1.1']['Z26'].value]
    glb['base' + i]['nstudgym11'] = [glb['wb' + i]['Раздел 2.1.1']['AA26'].value]

    glb['base' + i]['nclasseslyc'] = [glb['wb' + i]['Раздел 2.1.1']['P27'].value]
    glb['base' + i]['nclasseslyc1'] = [glb['wb' + i]['Раздел 2.1.1']['Q27'].value]
    glb['base' + i]['nclasseslyc2'] = [glb['wb' + i]['Раздел 2.1.1']['R27'].value]
    glb['base' + i]['nclasseslyc3'] = [glb['wb' + i]['Раздел 2.1.1']['S27'].value]
    glb['base' + i]['nclasseslyc4'] = [glb['wb' + i]['Раздел 2.1.1']['T27'].value]
    glb['base' + i]['nclasseslyc5'] = [glb['wb' + i]['Раздел 2.1.1']['U27'].value]
    glb['base' + i]['nclasseslyc6'] = [glb['wb' + i]['Раздел 2.1.1']['V27'].value]
    glb['base' + i]['nclasseslyc7'] = [glb['wb' + i]['Раздел 2.1.1']['W27'].value]
    glb['base' + i]['nclasseslyc8'] = [glb['wb' + i]['Раздел 2.1.1']['X27'].value]
    glb['base' + i]['nclasseslyc9'] = [glb['wb' + i]['Раздел 2.1.1']['Y27'].value]
    glb['base' + i]['nclasseslyc10'] = [glb['wb' + i]['Раздел 2.1.1']['Z27'].value]
    glb['base' + i]['nclasseslyc11'] = [glb['wb' + i]['Раздел 2.1.1']['AA27'].value]

    glb['base' + i]['nstudlyc'] = [glb['wb' + i]['Раздел 2.1.1']['P28'].value]
    glb['base' + i]['nstudlyc1'] = [glb['wb' + i]['Раздел 2.1.1']['Q28'].value]
    glb['base' + i]['nstudlyc2'] = [glb['wb' + i]['Раздел 2.1.1']['R28'].value]
    glb['base' + i]['nstudlyc3'] = [glb['wb' + i]['Раздел 2.1.1']['S28'].value]
    glb['base' + i]['nstudlyc4'] = [glb['wb' + i]['Раздел 2.1.1']['T28'].value]
    glb['base' + i]['nstudlyc5'] = [glb['wb' + i]['Раздел 2.1.1']['U28'].value]
    glb['base' + i]['nstudlyc6'] = [glb['wb' + i]['Раздел 2.1.1']['V28'].value]
    glb['base' + i]['nstudlyc7'] = [glb['wb' + i]['Раздел 2.1.1']['W28'].value]
    glb['base' + i]['nstudlyc8'] = [glb['wb' + i]['Раздел 2.1.1']['X28'].value]
    glb['base' + i]['nstudlyc9'] = [glb['wb' + i]['Раздел 2.1.1']['Y28'].value]
    glb['base' + i]['nstudlyc10'] = [glb['wb' + i]['Раздел 2.1.1']['Z28'].value]
    glb['base' + i]['nstudlyc11'] = [glb['wb' + i]['Раздел 2.1.1']['AA28'].value]

    glb['base' + i]['nclassessimple'] = [glb['wb' + i]['Раздел 2.1.1']['P21'].value]
    glb['base' + i]['nclassessimple1'] = [glb['wb' + i]['Раздел 2.1.1']['Q21'].value]
    glb['base' + i]['nclassessimple2'] = [glb['wb' + i]['Раздел 2.1.1']['R21'].value]
    glb['base' + i]['nclassessimple3'] = [glb['wb' + i]['Раздел 2.1.1']['S21'].value]
    glb['base' + i]['nclassessimple4'] = [glb['wb' + i]['Раздел 2.1.1']['T21'].value]
    glb['base' + i]['nclassessimple5'] = [glb['wb' + i]['Раздел 2.1.1']['U21'].value]
    glb['base' + i]['nclassessimple6'] = [glb['wb' + i]['Раздел 2.1.1']['V21'].value]
    glb['base' + i]['nclassessimple7'] = [glb['wb' + i]['Раздел 2.1.1']['W21'].value]
    glb['base' + i]['nclassessimple8'] = [glb['wb' + i]['Раздел 2.1.1']['X21'].value]
    glb['base' + i]['nclassessimple9'] = [glb['wb' + i]['Раздел 2.1.1']['Y21'].value]
    glb['base' + i]['nclassessimple10'] = [glb['wb' + i]['Раздел 2.1.1']['Z21'].value]
    glb['base' + i]['nclassessimple11'] = [glb['wb' + i]['Раздел 2.1.1']['AA21'].value]

    glb['base' + i]['nstudsimple'] = [glb['wb' + i]['Раздел 2.1.1']['P22'].value]
    glb['base' + i]['nstudsimple1'] = [glb['wb' + i]['Раздел 2.1.1']['Q22'].value]
    glb['base' + i]['nstudsimple2'] = [glb['wb' + i]['Раздел 2.1.1']['R22'].value]
    glb['base' + i]['nstudsimple3'] = [glb['wb' + i]['Раздел 2.1.1']['S22'].value]
    glb['base' + i]['nstudsimple4'] = [glb['wb' + i]['Раздел 2.1.1']['T22'].value]
    glb['base' + i]['nstudsimple5'] = [glb['wb' + i]['Раздел 2.1.1']['U22'].value]
    glb['base' + i]['nstudsimple6'] = [glb['wb' + i]['Раздел 2.1.1']['V22'].value]
    glb['base' + i]['nstudsimple7'] = [glb['wb' + i]['Раздел 2.1.1']['W22'].value]
    glb['base' + i]['nstudsimple8'] = [glb['wb' + i]['Раздел 2.1.1']['X22'].value]
    glb['base' + i]['nstudsimple9'] = [glb['wb' + i]['Раздел 2.1.1']['Y22'].value]
    glb['base' + i]['nstudsimple10'] = [glb['wb' + i]['Раздел 2.1.1']['Z22'].value]
    glb['base' + i]['nstudsimple11'] = [glb['wb' + i]['Раздел 2.1.1']['AA22'].value]

    glb['base' + i]['nstudochn'] = [glb['wb' + i]['Раздел 2.1.1']['P31'].value]
    glb['base' + i]['nstudochn1'] = [glb['wb' + i]['Раздел 2.1.1']['Q31'].value]
    glb['base' + i]['nstudochn2'] = [glb['wb' + i]['Раздел 2.1.1']['R31'].value]
    glb['base' + i]['nstudochn3'] = [glb['wb' + i]['Раздел 2.1.1']['S31'].value]
    glb['base' + i]['nstudochn4'] = [glb['wb' + i]['Раздел 2.1.1']['T31'].value]
    glb['base' + i]['nstudochn5'] = [glb['wb' + i]['Раздел 2.1.1']['U31'].value]
    glb['base' + i]['nstudochn6'] = [glb['wb' + i]['Раздел 2.1.1']['V31'].value]
    glb['base' + i]['nstudochn7'] = [glb['wb' + i]['Раздел 2.1.1']['W31'].value]
    glb['base' + i]['nstudochn8'] = [glb['wb' + i]['Раздел 2.1.1']['X31'].value]
    glb['base' + i]['nstudochn9'] = [glb['wb' + i]['Раздел 2.1.1']['Y31'].value]
    glb['base' + i]['nstudochn10'] = [glb['wb' + i]['Раздел 2.1.1']['Z31'].value]
    glb['base' + i]['nstudochn11'] = [glb['wb' + i]['Раздел 2.1.1']['AA31'].value]

    glb['base' + i]['nstudzaochn'] = [glb['wb' + i]['Раздел 2.1.1']['P33'].value]
    glb['base' + i]['nstudzaochn1'] = [glb['wb' + i]['Раздел 2.1.1']['Q33'].value]
    glb['base' + i]['nstudzaochn2'] = [glb['wb' + i]['Раздел 2.1.1']['R33'].value]
    glb['base' + i]['nstudzaochn3'] = [glb['wb' + i]['Раздел 2.1.1']['S33'].value]
    glb['base' + i]['nstudzaochn4'] = [glb['wb' + i]['Раздел 2.1.1']['T33'].value]
    glb['base' + i]['nstudzaochn5'] = [glb['wb' + i]['Раздел 2.1.1']['U33'].value]
    glb['base' + i]['nstudzaochn6'] = [glb['wb' + i]['Раздел 2.1.1']['V33'].value]
    glb['base' + i]['nstudzaochn7'] = [glb['wb' + i]['Раздел 2.1.1']['W33'].value]
    glb['base' + i]['nstudzaochn8'] = [glb['wb' + i]['Раздел 2.1.1']['X33'].value]
    glb['base' + i]['nstudzaochn9'] = [glb['wb' + i]['Раздел 2.1.1']['Y33'].value]
    glb['base' + i]['nstudzaochn10'] = [glb['wb' + i]['Раздел 2.1.1']['Z33'].value]
    glb['base' + i]['nstudzaochn11'] = [glb['wb' + i]['Раздел 2.1.1']['AA33'].value]

    glb['base' + i]['nstudochnzaochn'] = [glb['wb' + i]['Раздел 2.1.1']['P32'].value]
    glb['base' + i]['nstudochnzaochn1'] = [glb['wb' + i]['Раздел 2.1.1']['Q32'].value]
    glb['base' + i]['nstudochnzaochn2'] = [glb['wb' + i]['Раздел 2.1.1']['R32'].value]
    glb['base' + i]['nstudochnzaochn3'] = [glb['wb' + i]['Раздел 2.1.1']['S32'].value]
    glb['base' + i]['nstudochnzaochn4'] = [glb['wb' + i]['Раздел 2.1.1']['T32'].value]
    glb['base' + i]['nstudochnzaochn5'] = [glb['wb' + i]['Раздел 2.1.1']['U32'].value]
    glb['base' + i]['nstudochnzaochn6'] = [glb['wb' + i]['Раздел 2.1.1']['V32'].value]
    glb['base' + i]['nstudochnzaochn7'] = [glb['wb' + i]['Раздел 2.1.1']['W32'].value]
    glb['base' + i]['nstudochnzaochn8'] = [glb['wb' + i]['Раздел 2.1.1']['X32'].value]
    glb['base' + i]['nstudochnzaochn9'] = [glb['wb' + i]['Раздел 2.1.1']['Y32'].value]
    glb['base' + i]['nstudochnzaochn10'] = [glb['wb' + i]['Раздел 2.1.1']['Z32'].value]
    glb['base' + i]['nstudochnzaochn11'] = [glb['wb' + i]['Раздел 2.1.1']['AA32'].value]
    glb['base' + i]['nstudochnzaochn6'] = [glb['wb' + i]['Раздел 2.1.1']['V32'].value]
    glb['base' + i]['nstudochnzaochn7'] = [glb['wb' + i]['Раздел 2.1.1']['W32'].value]
    glb['base' + i]['nstudochnzaochn8'] = [glb['wb' + i]['Раздел 2.1.1']['X32'].value]
    glb['base' + i]['nstudochnzaochn9'] = [glb['wb' + i]['Раздел 2.1.1']['Y32'].value]
    glb['base' + i]['nstudochnzaochn10'] = [glb['wb' + i]['Раздел 2.1.1']['Z32'].value]
    glb['base' + i]['nstudochnzaochn11'] = [glb['wb' + i]['Раздел 2.1.1']['AA32'].value]

    glb['base' + i]['nstudgirl'] = [glb['wb' + i]['Раздел 2.1.1']['P35'].value]
    glb['base' + i]['nstudgirl1'] = [glb['wb' + i]['Раздел 2.1.1']['Q35'].value]
    glb['base' + i]['nstudgirl2'] = [glb['wb' + i]['Раздел 2.1.1']['R35'].value]
    glb['base' + i]['nstudgirl3'] = [glb['wb' + i]['Раздел 2.1.1']['S35'].value]
    glb['base' + i]['nstudgirl4'] = [glb['wb' + i]['Раздел 2.1.1']['T35'].value]
    glb['base' + i]['nstudgirl5'] = [glb['wb' + i]['Раздел 2.1.1']['U35'].value]
    glb['base' + i]['nstudgirl6'] = [glb['wb' + i]['Раздел 2.1.1']['V35'].value]
    glb['base' + i]['nstudgirl7'] = [glb['wb' + i]['Раздел 2.1.1']['W35'].value]
    glb['base' + i]['nstudgirl8'] = [glb['wb' + i]['Раздел 2.1.1']['X35'].value]
    glb['base' + i]['nstudgirl9'] = [glb['wb' + i]['Раздел 2.1.1']['Y35'].value]
    glb['base' + i]['nstudgirl10'] = [glb['wb' + i]['Раздел 2.1.1']['Z35'].value]
    glb['base' + i]['nstudgirl11'] = [glb['wb' + i]['Раздел 2.1.1']['AA35'].value]
    glb['base' + i]['nstudovz'] = [glb['wb' + i]['Раздел 2.1.1']['P37'].value]
    glb['base' + i]['nstudovz1'] = [glb['wb' + i]['Раздел 2.1.1']['Q37'].value]
    glb['base' + i]['nstudovz2'] = [glb['wb' + i]['Раздел 2.1.1']['R37'].value]
    glb['base' + i]['nstudovz3'] = [glb['wb' + i]['Раздел 2.1.1']['S37'].value]
    glb['base' + i]['nstudovz4'] = [glb['wb' + i]['Раздел 2.1.1']['T37'].value]
    glb['base' + i]['nstudovz5'] = [glb['wb' + i]['Раздел 2.1.1']['U37'].value]
    glb['base' + i]['nstudovz6'] = [glb['wb' + i]['Раздел 2.1.1']['V37'].value]
    glb['base' + i]['nstudovz7'] = [glb['wb' + i]['Раздел 2.1.1']['W37'].value]
    glb['base' + i]['nstudovz8'] = [glb['wb' + i]['Раздел 2.1.1']['X37'].value]
    glb['base' + i]['nstudovz9'] = [glb['wb' + i]['Раздел 2.1.1']['Y37'].value]
    glb['base' + i]['nstudovz10'] = [glb['wb' + i]['Раздел 2.1.1']['Z37'].value]
    glb['base' + i]['nstudovz11'] = [glb['wb' + i]['Раздел 2.1.1']['AA37'].value]
    glb['base' + i]['nstudgrad'] = [glb['wb' + i]['Раздел 2.5.1']['P21'].value]
    glb['base' + i]['nstudgrad1'] = [glb['wb' + i]['Раздел 2.5.1']['Q21'].value]
    glb['base' + i]['nstudgrad2'] = [glb['wb' + i]['Раздел 2.5.1']['R21'].value]
    glb['base' + i]['nstudgrad3'] = [glb['wb' + i]['Раздел 2.5.1']['S21'].value]
    glb['base' + i]['nstudgrad4'] = [glb['wb' + i]['Раздел 2.5.1']['T21'].value]
    glb['base' + i]['nstudgrad5'] = [glb['wb' + i]['Раздел 2.5.1']['U21'].value]
    glb['base' + i]['nstudgrad6'] = [glb['wb' + i]['Раздел 2.5.1']['V21'].value]
    glb['base' + i]['nstudgrad7'] = [glb['wb' + i]['Раздел 2.5.1']['W21'].value]
    glb['base' + i]['nstudgrad8'] = [glb['wb' + i]['Раздел 2.5.1']['X21'].value]
    glb['base' + i]['nstudgrad9'] = [glb['wb' + i]['Раздел 2.5.1']['Y21'].value]
    glb['base' + i]['nstudgrad10'] = [glb['wb' + i]['Раздел 2.5.1']['Z21'].value]
    glb['base' + i]['nstudgrad11'] = [glb['wb' + i]['Раздел 2.5.1']['AA21'].value]
    glb['base' + i]['nstudsem11'] = [glb['wb' + i]['Раздел 2.5.1']['AA26'].value]
    glb['base' + i]['nstudsem'] = [glb['wb' + i]['Раздел 2.5.1']['P26'].value]
    glb['base' + i]['nstudsem1'] = [glb['wb' + i]['Раздел 2.5.1']['Q26'].value]
    glb['base' + i]['nstudsem2'] = [glb['wb' + i]['Раздел 2.5.1']['R26'].value]
    glb['base' + i]['nstudsem3'] = [glb['wb' + i]['Раздел 2.5.1']['S26'].value]
    glb['base' + i]['nstudsem4'] = [glb['wb' + i]['Раздел 2.5.1']['T26'].value]
    glb['base' + i]['nstudsem5'] = [glb['wb' + i]['Раздел 2.5.1']['U26'].value]
    glb['base' + i]['nstudsem6'] = [glb['wb' + i]['Раздел 2.5.1']['V26'].value]
    glb['base' + i]['nstudsem7'] = [glb['wb' + i]['Раздел 2.5.1']['W26'].value]
    glb['base' + i]['nstudsem8'] = [glb['wb' + i]['Раздел 2.5.1']['X26'].value]
    glb['base' + i]['nstudsem9'] = [glb['wb' + i]['Раздел 2.5.1']['Y26'].value]
    glb['base' + i]['nstudsem10'] = [glb['wb' + i]['Раздел 2.5.1']['Z26'].value]
    glb['base' + i]['nstudsem11'] = [glb['wb' + i]['Раздел 2.5.1']['AA26'].value]
    glb['base' + i]['11otl'] = [glb['wb' + i]['Раздел 2.6']['P33'].value]
    glb['base' + i]['oge'] = [glb['wb' + i]['Раздел 2.6']['P21'].value]
    glb['base' + i]['ogeatt'] = [glb['wb' + i]['Раздел 2.6']['P22'].value]
    glb['base' + i]['9stayatschool'] = [glb['wb' + i]['Раздел 2.6']['P23'].value]
    glb['base' + i]['ogefail'] = [glb['wb' + i]['Раздел 2.6']['P24'].value]
    glb['base' + i]['9otl'] = [glb['wb' + i]['Раздел 2.6']['P26'].value]
    glb['base' + i]['ege'] = [glb['wb' + i]['Раздел 2.6']['P36'].value]
    glb['base' + i]['egerusuch'] = [glb['wb' + i]['Раздел 2.6']['P37'].value]
    glb['base' + i]['egerussdan'] = [glb['wb' + i]['Раздел 2.6']['P38'].value]
    glb['base' + i]['egemathuch'] = [glb['wb' + i]['Раздел 2.6']['P39'].value]
    glb['base' + i]['egemathuch'] = [glb['wb' + i]['Раздел 2.6']['P39'].value]
    glb['base' + i]['egemathsdan'] = [glb['wb' + i]['Раздел 2.6']['P40'].value]
    glb['base' + i]['11otl'] = [glb['wb' + i]['Раздел 2.6']['P33'].value]
    glb['base' + i]['11gonespokrs'] = [glb['wb' + i]['Раздел 2.8']['S29'].value]
    glb['base' + i]['9gonespokrs'] = [glb['wb' + i]['Раздел 2.8']['R28'].value]
    glb['base' + i]['9gonespokrs'] = [glb['wb' + i]['Раздел 2.8']['R29'].value]
    glb['base' + i]['11gonespokrs'] = [glb['wb' + i]['Раздел 2.8']['S28'].value]
    glb['base' + i]['11gonespokrs'] = [glb['wb' + i]['Раздел 2.8']['S29'].value]
    glb['base' + i]['langkitsred'] = [glb['wb' + i]['Раздел 2.10']['R28'].value]
    glb['base' + i]['langengnach'] = [glb['wb' + i]['Раздел 2.10']['P23'].value]
    glb['base' + i]['langengosn'] = [glb['wb' + i]['Раздел 2.10']['Q23'].value]
    glb['base' + i]['langengsred'] = [glb['wb' + i]['Раздел 2.10']['R23'].value]

    glb['base' + i]['langfrnach'] = [glb['wb' + i]['Раздел 2.10']['Q24'].value]
    glb['base' + i]['langfrosn'] = [glb['wb' + i]['Раздел 2.10']['R24'].value]
    glb['base' + i]['langfrsred'] = [glb['wb' + i]['Раздел 2.10']['R24'].value]

    glb['base' + i]['langnemnach'] = [glb['wb' + i]['Раздел 2.10']['Q25'].value]
    glb['base' + i]['langnemosn'] = [glb['wb' + i]['Раздел 2.10']['R25'].value]
    glb['base' + i]['langnemsred'] = [glb['wb' + i]['Раздел 2.10']['S25'].value]

    glb['base' + i]['langitnach'] = [glb['wb' + i]['Раздел 2.10']['P26'].value]
    glb['base' + i]['langitosn'] = [glb['wb' + i]['Раздел 2.10']['Q26'].value]
    glb['base' + i]['langitsred'] = [glb['wb' + i]['Раздел 2.10']['R26'].value]

    glb['base' + i]['langispnach'] = [glb['wb' + i]['Раздел 2.10']['P27'].value]
    glb['base' + i]['langisposn'] = [glb['wb' + i]['Раздел 2.10']['Q27'].value]
    glb['base' + i]['langispsred'] = [glb['wb' + i]['Раздел 2.10']['R27'].value]

    glb['base' + i]['langkitnach'] = [glb['wb' + i]['Раздел 2.10']['P28'].value]
    glb['base' + i]['langkitosn'] = [glb['wb' + i]['Раздел 2.10']['Q28'].value]
    glb['base' + i]['langkitsred'] = [glb['wb' + i]['Раздел 2.10']['R28'].value]
    glb['base' + i]['profclassmatsred'] = [glb['wb' + i]['Раздел 2.11']['R33'].value]
    glb['base' + i]['profclasshumnach'] = [glb['wb' + i]['Раздел 2.11']['P22'].value]
    glb['base' + i]['profclasshumosn'] = [glb['wb' + i]['Раздел 2.11']['Q22'].value]
    glb['base' + i]['profclasshumsred'] = [glb['wb' + i]['Раздел 2.11']['R22'].value]

    glb['base' + i]['profclassenauchnach'] = [glb['wb' + i]['Раздел 2.11']['P28'].value]
    glb['base' + i]['profclassenauchosn'] = [glb['wb' + i]['Раздел 2.11']['Q28'].value]
    glb['base' + i]['profclassenauchsred'] = [glb['wb' + i]['Раздел 2.11']['R28'].value]

    glb['base' + i]['profclasssoceconnach'] = [glb['wb' + i]['Раздел 2.11']['P29'].value]
    glb['base' + i]['profclasssoceconosn'] = [glb['wb' + i]['Раздел 2.11']['Q29'].value]
    glb['base' + i]['profclasssoceconsred'] = [glb['wb' + i]['Раздел 2.11']['R29'].value]

    glb['base' + i]['profclasstechnach'] = [glb['wb' + i]['Раздел 2.11']['P30'].value]
    glb['base' + i]['profclasstechosn'] = [glb['wb' + i]['Раздел 2.11']['Q30'].value]
    glb['base' + i]['profclasstechsred'] = [glb['wb' + i]['Раздел 2.11']['R30'].value]

    glb['base' + i]['profclassmatnach'] = [glb['wb' + i]['Раздел 2.11']['P33'].value]
    glb['base' + i]['profclassmatosn'] = [glb['wb' + i]['Раздел 2.11']['Q33'].value]
    glb['base' + i]['profclassmatsred'] = [glb['wb' + i]['Раздел 2.11']['R33'].value]
    glb['base' + i]['1011profsport'] = [glb['wb' + i]['Раздел 2.12']['Q35'].value]
    glb['base' + i]['1011profict'] = [glb['wb' + i]['Раздел 2.12']['Q23'].value]
    glb['base' + i]['1011profphismat'] = [glb['wb' + i]['Раздел 2.12']['Q27'].value]
    glb['base' + i]['1011profphischem'] = [glb['wb' + i]['Раздел 2.12']['Q28'].value]
    glb['base' + i]['1011profchembyo'] = [glb['wb' + i]['Раздел 2.12']['Q29'].value]
    glb['base' + i]['1011profbyogeo'] = [glb['wb' + i]['Раздел 2.12']['Q30'].value]
    glb['base' + i]['1011profsocecon'] = [glb['wb' + i]['Раздел 2.12']['Q31'].value]
    glb['base' + i]['1011profsochum'] = [glb['wb' + i]['Раздел 2.12']['Q32'].value]
    glb['base' + i]['1011profphyl'] = [glb['wb' + i]['Раздел 2.12']['Q33'].value]
    glb['base' + i]['1011profhud'] = [glb['wb' + i]['Раздел 2.12']['Q34'].value]
    glb['base' + i]['1011profsport'] = [glb['wb' + i]['Раздел 2.12']['Q35'].value]
    glb['base' + i]['dir'] = [glb['wb' + i]['Раздел 3.1']['P23'].value]
    glb['base' + i]['dirvo'] = [glb['wb' + i]['Раздел 3.1']['Q23'].value]
    glb['base' + i]['dirvpo'] = [glb['wb' + i]['Раздел 3.1']['R23'].value]
    glb['base' + i]['dircan'] = [glb['wb' + i]['Раздел 3.1']['T23'].value]
    glb['base' + i]['dirdoc'] = [glb['wb' + i]['Раздел 3.1']['S23'].value]
    glb['base' + i]['dirspo'] = [glb['wb' + i]['Раздел 3.1']['W23'].value]
    glb['base' + i]['dirspppo'] = [glb['wb' + i]['Раздел 3.1']['X23'].value]
    glb['base' + i]['dirhigh'] = [glb['wb' + i]['Раздел 3.1']['Z23'].value]
    glb['base' + i]['dirfirst'] = [glb['wb' + i]['Раздел 3.1']['AA23'].value]
    glb['base' + i]['dirfem'] = [glb['wb' + i]['Раздел 3.1']['AB23'].value]
    glb['base' + i]['dir'] = [glb['wb' + i]['Раздел 3.1']['P23'].value]
    glb['base' + i]['dirvo'] = [glb['wb' + i]['Раздел 3.1']['Q23'].value]
    glb['base' + i]['dirvpo'] = [glb['wb' + i]['Раздел 3.1']['R23'].value]
    glb['base' + i]['dircan'] = [glb['wb' + i]['Раздел 3.1']['T23'].value]
    glb['base' + i]['dirdoc'] = [glb['wb' + i]['Раздел 3.1']['S23'].value]
    glb['base' + i]['dirspo'] = [glb['wb' + i]['Раздел 3.1']['W23'].value]
    glb['base' + i]['dirspppo'] = [glb['wb' + i]['Раздел 3.1']['X23'].value]
    glb['base' + i]['dirhigh'] = [glb['wb' + i]['Раздел 3.1']['Z23'].value]
    glb['base' + i]['dirfirst'] = [glb['wb' + i]['Раздел 3.1']['AA23'].value]
    glb['base' + i]['dirfem'] = [glb['wb' + i]['Раздел 3.1']['AB23'].value]
    glb['base' + i]['zamdir'] = [glb['wb' + i]['Раздел 3.1']['P24'].value]
    glb['base' + i]['zamdirvo'] = [glb['wb' + i]['Раздел 3.1']['Q24'].value]
    glb['base' + i]['zamdirvpo'] = [glb['wb' + i]['Раздел 3.1']['R24'].value]
    glb['base' + i]['zamdircan'] = [glb['wb' + i]['Раздел 3.1']['T24'].value]
    glb['base' + i]['zamdirdoc'] = [glb['wb' + i]['Раздел 3.1']['S24'].value]
    glb['base' + i]['zamdirspo'] = [glb['wb' + i]['Раздел 3.1']['W24'].value]
    glb['base' + i]['zamdirspppo'] = [glb['wb' + i]['Раздел 3.1']['X24'].value]
    glb['base' + i]['zamdirhigh'] = [glb['wb' + i]['Раздел 3.1']['Z24'].value]
    glb['base' + i]['zamdirfirst'] = [glb['wb' + i]['Раздел 3.1']['AA24'].value]
    glb['base' + i]['zamdirfem'] = [glb['wb' + i]['Раздел 3.1']['AB24'].value]
    glb['base' + i]['teach'] = [glb['wb' + i]['Раздел 3.1']['P27'].value]
    glb['base' + i]['teachvo'] = [glb['wb' + i]['Раздел 3.1']['Q27'].value]
    glb['base' + i]['teachvpo'] = [glb['wb' + i]['Раздел 3.1']['R27'].value]
    glb['base' + i]['teachcan'] = [glb['wb' + i]['Раздел 3.1']['T27'].value]
    glb['base' + i]['teachdoc'] = [glb['wb' + i]['Раздел 3.1']['S27'].value]
    glb['base' + i]['teachspo'] = [glb['wb' + i]['Раздел 3.1']['W27'].value]
    glb['base' + i]['teachspppo'] = [glb['wb' + i]['Раздел 3.1']['X27'].value]
    glb['base' + i]['teachhigh'] = [glb['wb' + i]['Раздел 3.1']['Z27'].value]
    glb['base' + i]['teachfirst'] = [glb['wb' + i]['Раздел 3.1']['AA27'].value]
    glb['base' + i]['teachfem'] = [glb['wb' + i]['Раздел 3.1']['AB27'].value]
    glb['base' + i]['teachnach'] = [glb['wb' + i]['Раздел 3.1']['P28'].value]
    glb['base' + i]['teachnachvo'] = [glb['wb' + i]['Раздел 3.1']['Q28'].value]
    glb['base' + i]['teachnachvpo'] = [glb['wb' + i]['Раздел 3.1']['R28'].value]
    glb['base' + i]['teachnachcan'] = [glb['wb' + i]['Раздел 3.1']['T28'].value]
    glb['base' + i]['teachnachdoc'] = [glb['wb' + i]['Раздел 3.1']['S28'].value]
    glb['base' + i]['teachnachspo'] = [glb['wb' + i]['Раздел 3.1']['W28'].value]
    glb['base' + i]['teachnachspppo'] = [glb['wb' + i]['Раздел 3.1']['X28'].value]
    glb['base' + i]['teachnachhigh'] = [glb['wb' + i]['Раздел 3.1']['Z28'].value]
    glb['base' + i]['teachnachfirst'] = [glb['wb' + i]['Раздел 3.1']['AA28'].value]
    glb['base' + i]['teachnachfem'] = [glb['wb' + i]['Раздел 3.1']['AB28'].value]
    glb['base' + i]['teachrus'] = [glb['wb' + i]['Раздел 3.1']['P29'].value]
    glb['base' + i]['teachrusvo'] = [glb['wb' + i]['Раздел 3.1']['Q29'].value]
    glb['base' + i]['teachrusvpo'] = [glb['wb' + i]['Раздел 3.1']['R29'].value]
    glb['base' + i]['teachruscan'] = [glb['wb' + i]['Раздел 3.1']['T29'].value]
    glb['base' + i]['teachrusdoc'] = [glb['wb' + i]['Раздел 3.1']['S29'].value]
    glb['base' + i]['teachrusspo'] = [glb['wb' + i]['Раздел 3.1']['W29'].value]
    glb['base' + i]['teachrusspppo'] = [glb['wb' + i]['Раздел 3.1']['X29'].value]
    glb['base' + i]['teachrushigh'] = [glb['wb' + i]['Раздел 3.1']['Z29'].value]
    glb['base' + i]['teachrusfirst'] = [glb['wb' + i]['Раздел 3.1']['AA29'].value]
    glb['base' + i]['teachrusfem'] = [glb['wb' + i]['Раздел 3.1']['AB29'].value]
    glb['base' + i]['teachhist'] = [glb['wb' + i]['Раздел 3.1']['P31'].value]
    glb['base' + i]['teachhistvo'] = [glb['wb' + i]['Раздел 3.1']['Q31'].value]
    glb['base' + i]['teachhistvpo'] = [glb['wb' + i]['Раздел 3.1']['R31'].value]
    glb['base' + i]['teachhistcan'] = [glb['wb' + i]['Раздел 3.1']['T31'].value]
    glb['base' + i]['teachhistdoc'] = [glb['wb' + i]['Раздел 3.1']['S31'].value]
    glb['base' + i]['teachhistspo'] = [glb['wb' + i]['Раздел 3.1']['W31'].value]
    glb['base' + i]['teachhistspppo'] = [glb['wb' + i]['Раздел 3.1']['X31'].value]
    glb['base' + i]['teachhisthigh'] = [glb['wb' + i]['Раздел 3.1']['Z31'].value]
    glb['base' + i]['teachhistfirst'] = [glb['wb' + i]['Раздел 3.1']['AA31'].value]
    glb['base' + i]['teachhistfem'] = [glb['wb' + i]['Раздел 3.1']['AB31'].value]
    glb['base' + i]['teachict'] = [glb['wb' + i]['Раздел 3.1']['P32'].value]
    glb['base' + i]['teachictvo'] = [glb['wb' + i]['Раздел 3.1']['Q32'].value]
    glb['base' + i]['teachictvpo'] = [glb['wb' + i]['Раздел 3.1']['R32'].value]
    glb['base' + i]['teachictcan'] = [glb['wb' + i]['Раздел 3.1']['T32'].value]
    glb['base' + i]['teachictdoc'] = [glb['wb' + i]['Раздел 3.1']['S32'].value]
    glb['base' + i]['teachictspo'] = [glb['wb' + i]['Раздел 3.1']['W32'].value]
    glb['base' + i]['teachictspppo'] = [glb['wb' + i]['Раздел 3.1']['X32'].value]
    glb['base' + i]['teachicthigh'] = [glb['wb' + i]['Раздел 3.1']['Z32'].value]
    glb['base' + i]['teachictfirst'] = [glb['wb' + i]['Раздел 3.1']['AA32'].value]
    glb['base' + i]['teachictfem'] = [glb['wb' + i]['Раздел 3.1']['AB32'].value]
    glb['base' + i]['teachphys'] = [glb['wb' + i]['Раздел 3.1']['P33'].value]
    glb['base' + i]['teachphysvo'] = [glb['wb' + i]['Раздел 3.1']['Q33'].value]
    glb['base' + i]['teachphysvpo'] = [glb['wb' + i]['Раздел 3.1']['R33'].value]
    glb['base' + i]['teachphyscan'] = [glb['wb' + i]['Раздел 3.1']['T33'].value]
    glb['base' + i]['teachphysdoc'] = [glb['wb' + i]['Раздел 3.1']['S33'].value]
    glb['base' + i]['teachphysspo'] = [glb['wb' + i]['Раздел 3.1']['W33'].value]
    glb['base' + i]['teachphysspppo'] = [glb['wb' + i]['Раздел 3.1']['X33'].value]
    glb['base' + i]['teachphyshigh'] = [glb['wb' + i]['Раздел 3.1']['Z33'].value]
    glb['base' + i]['teachphysfirst'] = [glb['wb' + i]['Раздел 3.1']['AA33'].value]
    glb['base' + i]['teachphysfem'] = [glb['wb' + i]['Раздел 3.1']['AB33'].value]
    glb['base' + i]['teachmat'] = [glb['wb' + i]['Раздел 3.1']['P34'].value]
    glb['base' + i]['teachmatvo'] = [glb['wb' + i]['Раздел 3.1']['Q34'].value]
    glb['base' + i]['teachmatvpo'] = [glb['wb' + i]['Раздел 3.1']['R34'].value]
    glb['base' + i]['teachmatcan'] = [glb['wb' + i]['Раздел 3.1']['T34'].value]
    glb['base' + i]['teachmatdoc'] = [glb['wb' + i]['Раздел 3.1']['S34'].value]
    glb['base' + i]['teachmatspo'] = [glb['wb' + i]['Раздел 3.1']['W34'].value]
    glb['base' + i]['teachmatspppo'] = [glb['wb' + i]['Раздел 3.1']['X34'].value]
    glb['base' + i]['teachmathigh'] = [glb['wb' + i]['Раздел 3.1']['Z34'].value]
    glb['base' + i]['teachmatfirst'] = [glb['wb' + i]['Раздел 3.1']['AA34'].value]
    glb['base' + i]['teachmatfem'] = [glb['wb' + i]['Раздел 3.1']['AB34'].value]
    glb['base' + i]['teachchem'] = [glb['wb' + i]['Раздел 3.1']['P35'].value]
    glb['base' + i]['teachchemvo'] = [glb['wb' + i]['Раздел 3.1']['Q35'].value]
    glb['base' + i]['teachchemvpo'] = [glb['wb' + i]['Раздел 3.1']['R35'].value]
    glb['base' + i]['teachchemcan'] = [glb['wb' + i]['Раздел 3.1']['T35'].value]
    glb['base' + i]['teachchemdoc'] = [glb['wb' + i]['Раздел 3.1']['S35'].value]
    glb['base' + i]['teachchemspo'] = [glb['wb' + i]['Раздел 3.1']['W35'].value]
    glb['base' + i]['teachchemspppo'] = [glb['wb' + i]['Раздел 3.1']['X35'].value]
    glb['base' + i]['teachchemhigh'] = [glb['wb' + i]['Раздел 3.1']['Z35'].value]
    glb['base' + i]['teachchemfirst'] = [glb['wb' + i]['Раздел 3.1']['AA35'].value]
    glb['base' + i]['teachchemfem'] = [glb['wb' + i]['Раздел 3.1']['AB35'].value]
    glb['base' + i]['teachgeo'] = [glb['wb' + i]['Раздел 3.1']['P36'].value]
    glb['base' + i]['teachgeovo'] = [glb['wb' + i]['Раздел 3.1']['Q36'].value]
    glb['base' + i]['teachgeovpo'] = [glb['wb' + i]['Раздел 3.1']['R36'].value]
    glb['base' + i]['teachgeocan'] = [glb['wb' + i]['Раздел 3.1']['T36'].value]
    glb['base' + i]['teachgeodoc'] = [glb['wb' + i]['Раздел 3.1']['S36'].value]
    glb['base' + i]['teachgeospo'] = [glb['wb' + i]['Раздел 3.1']['W36'].value]
    glb['base' + i]['teachgeospppo'] = [glb['wb' + i]['Раздел 3.1']['X36'].value]
    glb['base' + i]['teachgeohigh'] = [glb['wb' + i]['Раздел 3.1']['Z36'].value]
    glb['base' + i]['teachgeofirst'] = [glb['wb' + i]['Раздел 3.1']['AA36'].value]
    glb['base' + i]['teachgeofem'] = [glb['wb' + i]['Раздел 3.1']['AB36'].value]
    glb['base' + i]['teachbio'] = [glb['wb' + i]['Раздел 3.1']['P37'].value]
    glb['base' + i]['teachbiovo'] = [glb['wb' + i]['Раздел 3.1']['Q37'].value]
    glb['base' + i]['teachbiovpo'] = [glb['wb' + i]['Раздел 3.1']['R37'].value]
    glb['base' + i]['teachbiocan'] = [glb['wb' + i]['Раздел 3.1']['T37'].value]
    glb['base' + i]['teachbiodoc'] = [glb['wb' + i]['Раздел 3.1']['S37'].value]
    glb['base' + i]['teachbiospo'] = [glb['wb' + i]['Раздел 3.1']['W37'].value]
    glb['base' + i]['teachbiospppo'] = [glb['wb' + i]['Раздел 3.1']['X37'].value]
    glb['base' + i]['teachbiohigh'] = [glb['wb' + i]['Раздел 3.1']['Z37'].value]
    glb['base' + i]['teachbiofirst'] = [glb['wb' + i]['Раздел 3.1']['AA37'].value]
    glb['base' + i]['teachbiofem'] = [glb['wb' + i]['Раздел 3.1']['AB37'].value]
    glb['base' + i]['teachlangfem'] = [glb['wb' + i]['Раздел 3.1']['AB38'].value]
    glb['base' + i]['teachlang'] = [glb['wb' + i]['Раздел 3.1']['P38'].value]
    glb['base' + i]['teachlangvo'] = [glb['wb' + i]['Раздел 3.1']['Q38'].value]
    glb['base' + i]['teachlangvpo'] = [glb['wb' + i]['Раздел 3.1']['R38'].value]
    glb['base' + i]['teachlangcan'] = [glb['wb' + i]['Раздел 3.1']['T38'].value]
    glb['base' + i]['teachlangdoc'] = [glb['wb' + i]['Раздел 3.1']['S38'].value]
    glb['base' + i]['teachlangspo'] = [glb['wb' + i]['Раздел 3.1']['W38'].value]
    glb['base' + i]['teachlangspppo'] = [glb['wb' + i]['Раздел 3.1']['X38'].value]
    glb['base' + i]['teachlanghigh'] = [glb['wb' + i]['Раздел 3.1']['Z38'].value]
    glb['base' + i]['teachlangfirst'] = [glb['wb' + i]['Раздел 3.1']['AA38'].value]
    glb['base' + i]['teachlangfem'] = [glb['wb' + i]['Раздел 3.1']['AB38'].value]
    glb['base' + i]['direxpless3'] = [glb['wb' + i]['Раздел 3.2']['Q23'].value]
    glb['base' + i]['zamdirexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q22'].value]
    glb['base' + i]['teachexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q27'].value]
    glb['base' + i]['teachnachexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q28'].value]
    glb['base' + i]['teachrusexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q29'].value]
    glb['base' + i]['teachhistexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q31'].value]
    glb['base' + i]['teachictexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q32'].value]
    glb['base' + i]['teachphysexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q33'].value]
    glb['base' + i]['teachmatexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q34'].value]
    glb['base' + i]['teachchemexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q35'].value]
    glb['base' + i]['teachgeoexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q36'].value]
    glb['base' + i]['teachbioexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q37'].value]
    glb['base' + i]['teachlangexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q38'].value]
    glb['base' + i]['direxpless3'] = [glb['wb' + i]['Раздел 3.2']['Q23'].value]
    glb['base' + i]['zamdirexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q22'].value]
    glb['base' + i]['teachexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q27'].value]
    glb['base' + i]['teachnachexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q28'].value]
    glb['base' + i]['teachrusexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q29'].value]
    glb['base' + i]['teachhistexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q31'].value]
    glb['base' + i]['teachictexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q32'].value]
    glb['base' + i]['teachphysexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q33'].value]
    glb['base' + i]['teachmatexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q34'].value]
    glb['base' + i]['teachchemexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q35'].value]
    glb['base' + i]['teachgeoexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q36'].value]
    glb['base' + i]['teachbioexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q37'].value]
    glb['base' + i]['teachlangexpless3'] = [glb['wb' + i]['Раздел 3.2']['Q38'].value]
    glb['base' + i]['direxp3_5'] = [glb['wb' + i]['Раздел 3.2']['R23'].value]
    glb['base' + i]['zamdirexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R22'].value]
    glb['base' + i]['teachexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R27'].value]
    glb['base' + i]['teachnachexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R28'].value]
    glb['base' + i]['teachrusexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R29'].value]
    glb['base' + i]['teachhistexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R31'].value]
    glb['base' + i]['teachictexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R32'].value]
    glb['base' + i]['teachphysexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R33'].value]
    glb['base' + i]['teachmatexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R34'].value]
    glb['base' + i]['teachchemexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R35'].value]
    glb['base' + i]['teachgeoexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R36'].value]
    glb['base' + i]['teachbioexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R37'].value]
    glb['base' + i]['teachlangexp3_5'] = [glb['wb' + i]['Раздел 3.2']['R38'].value]
    glb['base' + i]['direxp5_10'] = [glb['wb' + i]['Раздел 3.2']['S23'].value]
    glb['base' + i]['zamdirexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S22'].value]
    glb['base' + i]['teachexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S27'].value]
    glb['base' + i]['teachnachexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S28'].value]
    glb['base' + i]['teachSusexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S29'].value]
    glb['base' + i]['teachhistexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S31'].value]
    glb['base' + i]['teachictexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S32'].value]
    glb['base' + i]['teachphysexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S33'].value]
    glb['base' + i]['teachmatexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S34'].value]
    glb['base' + i]['teachchemexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S35'].value]
    glb['base' + i]['teachgeoexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S36'].value]
    glb['base' + i]['teachbioexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S37'].value]
    glb['base' + i]['teachlangexp5_10'] = [glb['wb' + i]['Раздел 3.2']['S38'].value]
    glb['base' + i]['direxp10_15'] = [glb['wb' + i]['Раздел 3.2']['T23'].value]
    glb['base' + i]['zamdirexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T22'].value]
    glb['base' + i]['teachexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T27'].value]
    glb['base' + i]['teachnachexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T28'].value]
    glb['base' + i]['teachrusexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T29'].value]
    glb['base' + i]['teachhistexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T31'].value]
    glb['base' + i]['teachictexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T32'].value]
    glb['base' + i]['teachphysexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T33'].value]
    glb['base' + i]['teachmatexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T34'].value]
    glb['base' + i]['teachchemexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T35'].value]
    glb['base' + i]['teachgeoexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T36'].value]
    glb['base' + i]['teachbioexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T37'].value]
    glb['base' + i]['teachlangexp10_15'] = [glb['wb' + i]['Раздел 3.2']['T38'].value]
    glb['base' + i]['direxp15_20'] = [glb['wb' + i]['Раздел 3.2']['U23'].value]
    glb['base' + i]['zamdirexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U22'].value]
    glb['base' + i]['teachexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U27'].value]
    glb['base' + i]['teachnachexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U28'].value]
    glb['base' + i]['teachrusexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U29'].value]
    glb['base' + i]['teachhistexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U31'].value]
    glb['base' + i]['teachictexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U32'].value]
    glb['base' + i]['teachphysexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U33'].value]
    glb['base' + i]['teachmatexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U34'].value]
    glb['base' + i]['teachchemexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U35'].value]
    glb['base' + i]['teachgeoexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U36'].value]
    glb['base' + i]['teachbioexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U37'].value]
    glb['base' + i]['teachlangexp15_20'] = [glb['wb' + i]['Раздел 3.2']['U38'].value]
    glb['base' + i]['direxpmore20'] = [glb['wb' + i]['Раздел 3.2']['V23'].value]
    glb['base' + i]['zamdirexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V22'].value]
    glb['base' + i]['teachexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V27'].value]
    glb['base' + i]['teachnachexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V28'].value]
    glb['base' + i]['teachrusexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V29'].value]
    glb['base' + i]['teachhistexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V31'].value]
    glb['base' + i]['teachictexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V32'].value]
    glb['base' + i]['teachphysexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V33'].value]
    glb['base' + i]['teachmatexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V34'].value]
    glb['base' + i]['teachchemexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V35'].value]
    glb['base' + i]['teachgeoexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V36'].value]
    glb['base' + i]['teachbioexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V37'].value]
    glb['base' + i]['teachlangexpmore20'] = [glb['wb' + i]['Раздел 3.2']['V38'].value]
    glb['base' + i]['dirageless25'] = [glb['wb' + i]['Раздел 3.5']['Q23'].value]
    glb['base' + i]['zamdirageless25'] = [glb['wb' + i]['Раздел 3.5']['Q22'].value]
    glb['base' + i]['teachageless25'] = [glb['wb' + i]['Раздел 3.5']['Q27'].value]
    glb['base' + i]['teachnachageless25'] = [glb['wb' + i]['Раздел 3.5']['Q28'].value]
    glb['base' + i]['teachrusageless25'] = [glb['wb' + i]['Раздел 3.5']['Q29'].value]
    glb['base' + i]['teachhistageless25'] = [glb['wb' + i]['Раздел 3.5']['Q31'].value]
    glb['base' + i]['teachictageless25'] = [glb['wb' + i]['Раздел 3.5']['Q32'].value]
    glb['base' + i]['teachphysageless25'] = [glb['wb' + i]['Раздел 3.5']['Q33'].value]
    glb['base' + i]['teachmatageless25'] = [glb['wb' + i]['Раздел 3.5']['Q34'].value]
    glb['base' + i]['teachchemageless25'] = [glb['wb' + i]['Раздел 3.5']['Q35'].value]
    glb['base' + i]['teachgeoageless25'] = [glb['wb' + i]['Раздел 3.5']['Q36'].value]
    glb['base' + i]['teachbioageless25'] = [glb['wb' + i]['Раздел 3.5']['Q37'].value]
    glb['base' + i]['teachlangageless25'] = [glb['wb' + i]['Раздел 3.5']['Q38'].value]
    glb['base' + i]['dirage25_29'] = [glb['wb' + i]['Раздел 3.5']['S23'].value]
    glb['base' + i]['zamdirage25_29'] = [glb['wb' + i]['Раздел 3.5']['S22'].value]
    glb['base' + i]['teachage25_29'] = [glb['wb' + i]['Раздел 3.5']['S27'].value]
    glb['base' + i]['teachnachage25_29'] = [glb['wb' + i]['Раздел 3.5']['S28'].value]
    glb['base' + i]['teachrusage25_29'] = [glb['wb' + i]['Раздел 3.5']['S29'].value]
    glb['base' + i]['teachhistage25_29'] = [glb['wb' + i]['Раздел 3.5']['S31'].value]
    glb['base' + i]['teachictage25_29'] = [glb['wb' + i]['Раздел 3.5']['S32'].value]
    glb['base' + i]['teachphysage25_29'] = [glb['wb' + i]['Раздел 3.5']['S33'].value]
    glb['base' + i]['teachmatage25_29'] = [glb['wb' + i]['Раздел 3.5']['S34'].value]
    glb['base' + i]['teachchemage25_29'] = [glb['wb' + i]['Раздел 3.5']['S35'].value]
    glb['base' + i]['teachgeoage25_29'] = [glb['wb' + i]['Раздел 3.5']['S36'].value]
    glb['base' + i]['teachbioage25_29'] = [glb['wb' + i]['Раздел 3.5']['S37'].value]
    glb['base' + i]['teachlangage25_29'] = [glb['wb' + i]['Раздел 3.5']['S38'].value]
    glb['base' + i]['dirage30_34'] = [glb['wb' + i]['Раздел 3.5']['U23'].value]
    glb['base' + i]['zamdirage30_34'] = [glb['wb' + i]['Раздел 3.5']['U22'].value]
    glb['base' + i]['teachage30_34'] = [glb['wb' + i]['Раздел 3.5']['U27'].value]
    glb['base' + i]['teachnachage30_34'] = [glb['wb' + i]['Раздел 3.5']['U28'].value]
    glb['base' + i]['teachrusage30_34'] = [glb['wb' + i]['Раздел 3.5']['U29'].value]
    glb['base' + i]['teachhistage30_34'] = [glb['wb' + i]['Раздел 3.5']['U31'].value]
    glb['base' + i]['teachictage30_34'] = [glb['wb' + i]['Раздел 3.5']['U32'].value]
    glb['base' + i]['teachphysage30_34'] = [glb['wb' + i]['Раздел 3.5']['U33'].value]
    glb['base' + i]['teachmatage30_34'] = [glb['wb' + i]['Раздел 3.5']['U34'].value]
    glb['base' + i]['teachchemage30_34'] = [glb['wb' + i]['Раздел 3.5']['U35'].value]
    glb['base' + i]['teachgeoage30_34'] = [glb['wb' + i]['Раздел 3.5']['U36'].value]
    glb['base' + i]['teachbioage30_34'] = [glb['wb' + i]['Раздел 3.5']['U37'].value]
    glb['base' + i]['teachlangage30_34'] = [glb['wb' + i]['Раздел 3.5']['U38'].value]
    glb['base' + i]['dirage35_39'] = [glb['wb' + i]['Раздел 3.5']['W23'].value]
    glb['base' + i]['zamdirage35_39'] = [glb['wb' + i]['Раздел 3.5']['W22'].value]
    glb['base' + i]['teachage35_39'] = [glb['wb' + i]['Раздел 3.5']['W27'].value]
    glb['base' + i]['teachnachage35_39'] = [glb['wb' + i]['Раздел 3.5']['W28'].value]
    glb['base' + i]['teachrusage35_39'] = [glb['wb' + i]['Раздел 3.5']['W29'].value]
    glb['base' + i]['teachhistage35_39'] = [glb['wb' + i]['Раздел 3.5']['W31'].value]
    glb['base' + i]['teachictage35_39'] = [glb['wb' + i]['Раздел 3.5']['W32'].value]
    glb['base' + i]['teachphysage35_39'] = [glb['wb' + i]['Раздел 3.5']['W33'].value]
    glb['base' + i]['teachmatage35_39'] = [glb['wb' + i]['Раздел 3.5']['W34'].value]
    glb['base' + i]['teachchemage35_39'] = [glb['wb' + i]['Раздел 3.5']['W35'].value]
    glb['base' + i]['teachgeoage35_39'] = [glb['wb' + i]['Раздел 3.5']['W36'].value]
    glb['base' + i]['teachbioage35_39'] = [glb['wb' + i]['Раздел 3.5']['W37'].value]
    glb['base' + i]['teachlangage35_39'] = [glb['wb' + i]['Раздел 3.5']['W38'].value]
    glb['base' + i]['dirage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y23'].value]
    glb['base' + i]['zamdirage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y22'].value]
    glb['base' + i]['teachage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y27'].value]
    glb['base' + i]['teachnachage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y28'].value]
    glb['base' + i]['teachrusage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y29'].value]
    glb['base' + i]['teachhistage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y31'].value]
    glb['base' + i]['teachictage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y32'].value]
    glb['base' + i]['teachphysage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y33'].value]
    glb['base' + i]['teachmatage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y34'].value]
    glb['base' + i]['teachchemage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y35'].value]
    glb['base' + i]['teachgeoage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y36'].value]
    glb['base' + i]['teachbioage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y37'].value]
    glb['base' + i]['teachlangage40_44'] = [glb['wb' + i]['Раздел 3.5']['Y38'].value]
    glb['base' + i]['dirage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA23'].value]
    glb['base' + i]['zamdirage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA22'].value]
    glb['base' + i]['teachage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA27'].value]
    glb['base' + i]['teachnachage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA28'].value]
    glb['base' + i]['teachrusage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA29'].value]
    glb['base' + i]['teachhistage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA31'].value]
    glb['base' + i]['teachictage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA32'].value]
    glb['base' + i]['teachphysage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA33'].value]
    glb['base' + i]['teachmatage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA34'].value]
    glb['base' + i]['teachchemage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA35'].value]
    glb['base' + i]['teachgeoage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA36'].value]
    glb['base' + i]['teachbioage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA37'].value]
    glb['base' + i]['teachlangage45_49'] = [glb['wb' + i]['Раздел 3.5']['AA38'].value]
    glb['base' + i]['dirage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC23'].value]
    glb['base' + i]['zamdirage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC22'].value]
    glb['base' + i]['teachage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC27'].value]
    glb['base' + i]['teachnachage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC28'].value]
    glb['base' + i]['teachrusage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC29'].value]
    glb['base' + i]['teachhistage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC31'].value]
    glb['base' + i]['teachictage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC32'].value]
    glb['base' + i]['teachphysage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC33'].value]
    glb['base' + i]['teachmatage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC34'].value]
    glb['base' + i]['teachchemage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC35'].value]
    glb['base' + i]['teachgeoage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC36'].value]
    glb['base' + i]['teachbioage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC37'].value]
    glb['base' + i]['teachlangage50_54'] = [glb['wb' + i]['Раздел 3.5']['AC38'].value]
    glb['base' + i]['dirage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE23'].value]
    glb['base' + i]['zamdirage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE22'].value]
    glb['base' + i]['teachage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE27'].value]
    glb['base' + i]['teachnachage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE28'].value]
    glb['base' + i]['teachrusage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE29'].value]
    glb['base' + i]['teachhistage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE31'].value]
    glb['base' + i]['teachictage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE32'].value]
    glb['base' + i]['teachphysage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE33'].value]
    glb['base' + i]['teachmatage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE34'].value]
    glb['base' + i]['teachchemage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE35'].value]
    glb['base' + i]['teachgeoage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE36'].value]
    glb['base' + i]['teachbioage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE37'].value]
    glb['base' + i]['teachlangage55_59'] = [glb['wb' + i]['Раздел 3.5']['AE38'].value]
    glb['base' + i]['dirage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG23'].value]
    glb['base' + i]['zamdirage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG22'].value]
    glb['base' + i]['teachage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG27'].value]
    glb['base' + i]['teachnachage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG28'].value]
    glb['base' + i]['teachrusage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG29'].value]
    glb['base' + i]['teachhistage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG31'].value]
    glb['base' + i]['teachictage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG32'].value]
    glb['base' + i]['teachphysage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG33'].value]
    glb['base' + i]['teachmatage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG34'].value]
    glb['base' + i]['teachchemage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG35'].value]
    glb['base' + i]['teachgeoage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG36'].value]
    glb['base' + i]['teachbioage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG37'].value]
    glb['base' + i]['teachlangage60_64'] = [glb['wb' + i]['Раздел 3.5']['AG38'].value]
    glb['base' + i]['diragemore65'] = [glb['wb' + i]['Раздел 3.5']['AI23'].value]
    glb['base' + i]['zamdiragemore65'] = [glb['wb' + i]['Раздел 3.5']['AI22'].value]
    glb['base' + i]['teachagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI27'].value]
    glb['base' + i]['teachnachagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI28'].value]
    glb['base' + i]['teachrusagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI29'].value]
    glb['base' + i]['teachhistagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI31'].value]
    glb['base' + i]['teachictagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI32'].value]
    glb['base' + i]['teachphysagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI33'].value]
    glb['base' + i]['teachmatagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI34'].value]
    glb['base' + i]['teachchemagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI35'].value]
    glb['base' + i]['teachgeoagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI36'].value]
    glb['base' + i]['teachbioagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI37'].value]
    glb['base' + i]['teachlangagemore65'] = [glb['wb' + i]['Раздел 3.5']['AI38'].value]
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# <ipython-input-7-de259a6e70d8>:261: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   glb['base' + i]['nstudsem9'] = [glb['wb' + i]['Раздел 2.5.1']['Y26'].value]
# <ipython-input-7-de259a6e70d8>:262: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   glb['base' + i]['nstudsem10'] = [glb['wb' + i]['Раздел 2.5.1']['Z26'].value]
# ...

# %%
oo_1_2020 = base1

# %%
for i in range(2, 86):
    i = str(i)
    oo_1_2020 = pd.concat([oo_1_2020, glb['base' + i]])

# %%
oo_1_2020.to_excel('oo1_2022-23.xlsx', index = False, encoding = 'unicode8')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
